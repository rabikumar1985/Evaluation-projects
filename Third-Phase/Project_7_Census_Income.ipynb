# %% [markdown]
# ## Census Income

# %% [markdown]
# #### Project Description
#
# This data was extracted from the 1994 Census bureau database by Ronny Kohavi and Barry Becker (Data Mining and Visualization, Silicon Graphics). A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1) && (HRSWK>0)). The prediction task is to determine whether a person makes over $50K a year.
#
# #### Description of fnlwgt (final weight)
#
# The weights on the Current Population Survey (CPS) files are controlled to independent estimates of the civilian non-institutional population of the US. These are prepared monthly for us by Population Division here at the Census Bureau. We use 3 sets of controls. These are:
#
# 1.	A single cell estimate of the population 16+ for each state.
#
# 2.	Controls for Hispanic Origin by age and sex.
#
# 3.	Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.

# %% [markdown]
# #### Dataset Link-
#
# https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv

# %%
# Import Necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing DataSet

df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %% [markdown]
# #### Statistical Exploration of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# We have 32560 observations and 15 columns, dataset has mix of data types.

# %%
# check if any duplicate entry or duplicate row with same value exist

df.duplicated().sum()
# Out:
# 24

# %%
# Let check how many question mark (" ?") inside dataset.

df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
# Let check if any whitespace, 'NA' or '-' exist in dataset.

df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
# Let replace ' ?' with np.NaN

df=df.replace(' ?',np.NaN)

# %% [markdown]
# Comment:
#
# We have Replace ' ?' with np.NaN
#
# No whitespace, NA, '-' exist in dataset.

# %%
# Let drop duplicated entry from dataset before checking null values.

df.drop_duplicates(keep='last', inplace=True)

# %%
df.shape
# Out:
# (32536, 15)

# %% [markdown]
# #### Missing value check

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Finding what percentage of data is missing from the dataset

missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Occupation                1843        5.664495
# Workclass                 1836        5.642980
# Native_country             582        1.788788
# Age                          0        0.000000
# Fnlwgt                       0        0.000000
# Education                    0        0.000000
# Education_num                0        0.000000
# Marital_status               0        0.000000
# Relationship                 0        0.000000
# Race                         0        0.000000
# Sex                          0        0.000000
# Capital_gain                 0        0.000000
# Capital_loss                 0        0.000000
# Hours_per_week               0        0.000000
# Income                       0        0.000000

# %% [markdown]
# Comment:
#
# There are missing values in Occupation,workclass, Native country.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32536 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32536 non-null  int64
#  1   Workclass       30700 non-null  object
#  2   Fnlwgt          32536 non-null  int64
#  3   Education       32536 non-null  object
#  4   Education_num   32536 non-null  int64
#  5   Marital_status  32536 non-null  object
#  6   Occupation      30693 non-null  object
#  7   Relationship    32536 non-null  object
#  8   Race            32536 non-null  object
#  9   Sex             32536 non-null  object
#  10  Capital_gain    32536 non-null  int64
#  11  Capital_loss    32536 non-null  int64
#  12  Hours_per_week  32536 non-null  int64
#  13  Native_country  31954 non-null  object
#  14  Income          32536 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# Observation:
#
# There are 32536 rows , 14 Independent columns and 1 Target feature.
#
# Age,Fnlwgt, education_num, capital gain, capital loss, hours per week are Numerical variable and having int64 datatypes.
#
# Work class, Education,Marital status, occupation, relationship, race,sex,native country are categorical feature with object datatypes.

# %%
# Separating numerical and categorical variable

Numerical=['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']

Category=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']

# %% [markdown]
# #### Missing value imputation

# %%
# Imputating Missing value with mode for categorical features

df['Occupation'].fillna(df['Occupation'].mode()[0],inplace=True)
df['Workclass'].fillna(df['Workclass'].mode()[0],inplace=True)
df['Native_country'].fillna(df['Native_country'].mode()[0],inplace=True)

# %% [markdown]
# #### Missing Value Check After Imputataion

# %%
# Finding what percentage of data is missing from the dataset

missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Age                          0             0.0
# Workclass                    0             0.0
# Fnlwgt                       0             0.0
# Education                    0             0.0
# Education_num                0             0.0
# Marital_status               0             0.0
# Occupation                   0             0.0
# Relationship                 0             0.0
# Race                         0             0.0
# Sex                          0             0.0
# Capital_gain                 0             0.0
# Capital_loss                 0             0.0
# Hours_per_week               0             0.0
# Native_country               0             0.0
# Income                       0             0.0

# %% [markdown]
# Comment :
#
# Finally, No Missing Value is Present.

# %%
# Statistical Matrix

df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32536.000000  3.253600e+04   32536.000000  32536.000000  32536.000000
# mean      38.585536  1.897843e+05      10.081725   1078.410069     87.370912
# std       13.638193  1.055563e+05       2.571622   7388.068465    403.107737
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369932e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32536.000000
# mean        40.440343
# std         12.347079
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Observation:
#
# The minimum and maximum age of people in the dataset is 17 and 90 years respectively, while the average age is 37.
#
# The minimum and maximum years spent on education is 1 and 16 respectively, whereas the mean education level is 10 years.
#
# While the minimum and average capital gain is 0, maximum is 99999. This seems odd, maybe some error within the data collection.
#
# The number of hours spent per week varies between 1 to 99 and the average being 40 hours.

# %%
# Start Exploring categorial features with Enlisting Value counts & Sub-categories

for i in Category:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Workclass
#  Private             24509
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ====================================================================================================
# Education
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name: Education, dtype: int64
# ====================================================================================================
# Marital_status
#  Married-civ-spouse       14970
#  Never-married            10666
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ====================================================================================================
# Occupation
#  Prof-specialty       5979
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3767
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ====================================================================================================
# Relationship
#  Husband           13187
#  Not-in-family      8291
#  Own-child          5064
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ====================================================================================================
# Race
#  White                 27794
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ====================================================================================================
# Sex
#  Male      21774
#  Female    10762
# Name: Sex, dtype: int64
# ====================================================================================================
# Native_country
#  United-States                 29734
#  Mexico                          639
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Japan                            62
#  Guatemala                        62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ====================================================================================================
# Income
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64
# ====================================================================================================

# %% [markdown]
# #### Exploratory Data Analysis(EDA)

# %%
# Start EDA by analysing our target variable first.

plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,10))
df['Income'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Income',data=df,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Observation :
#
# 75.9 % population (24697 peoples) have income less than 50K.
#
# Our task is to predict income and we see that target variable income is imbalanced.

# %%
# Exploration of Age

print('Minimum Age:', df['Age'].min(),'years')
print('Maximum Age:', df['Age'].max(),'years')
print('Average Age:', df['Age'].mean(),'years')
# Out:
# Minimum Age: 17 years
# Maximum Age: 90 years
# Average Age: 38.58553602163757 years

# %%
# Defining function to create new columns to classify people according different age gruop

def age_group(x):
    x = int(x)
    x = abs(x)
    if (18 < x < 31):
        return "19-30"
    if (30 < x < 41) :
        return '31-40'
    if (40 < x <51):
        return '41-50'
    if (50 < x < 61):
        return "51-60"
    if (60 < x < 71):
        return "61-70"
    else :
        return 'Greater Than 70'

# %%
# Calling function age_group

df['age_group']=df['Age'].apply(age_group)

# %%
plt.figure(figsize=(12,6))
order_list = ['19-30','31-40','41-50','51-60','61-70','Greater Than 70']
p = sns.countplot(x=df['age_group'], hue=df['Income'], palette='hsv', order=order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=22, fontweight='bold')
p.set_xlabel('Age Groups')
plt.xticks(fontsize=16,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Distribution of age with income categories
ax= sns.FacetGrid(df,col='Income')
ax.map(sns.distplot,'Age')
plt.show()

# %% [markdown]
# Observation:
#
# Here comes an interesting observation. We already know that only 24% people earnings more than 50K dollors and this plot tell us which age group then belong.
#
# almost 10 % people in age group of 19-30 earns more than 50 K dollars and this count drop even more in old peoples having age greater than 70. Might be some lucky old ones has created good Retirement Plan compare to rest old peoples.
#
# We can find maximum people earning more than 50K dollors belong to age group 41-50 & 51-60. It will be interesting to find out which profession lead this income to this category.

# %%
# So let dive into workclass and see what insight we get from there.

plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Workclass'].value_counts().plot.pie(explode=[0,0.1,0.125,0.175,0.225,0.25,0.3,0.7],autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Workclass', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(x=df['Workclass'], hue=df['Income'], palette='hsv')
plt.title('Income distribution as per Workclass', fontsize=22, fontweight='bold')
p.set_xlabel('Workclass',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
pd.crosstab(df['Income'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_97d6b_row0_col0 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_97d6b_row0_col1 {
#   background-color: #6bb566;
#   color: #f1f1f1;
# }
# #T_97d6b_row0_col2, #T_97d6b_row0_col7, #T_97d6b_row2_col0, #T_97d6b_row2_col1, #T_97d6b_row2_col2, #T_97d6b_row2_col3, #T_97d6b_row2_col4, #T_97d6b_row2_col5, #T_97d6b_row2_col6, #T_97d6b_row2_col7, #T_97d6b_row2_col8 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_97d6b_row0_col3 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_97d6b_row0_col4, #T_97d6b_row1_col0, #T_97d6b_row1_col1, #T_97d6b_row1_col2, #T_97d6b_row1_col3, #T_97d6b_row1_col5, #T_97d6b_row1_col6, #T_97d6b_row1_col7, #T_97d6b_row1_col8 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_97d6b_row0_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_97d6b_row0_col6 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_97d6b_row0_col8 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_97d6b_row1_col4 {
#   background-color: #cbe566;
#   color: #000000;
# }
# </style>
# <table id="T_97d6b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Workclass</th>
#       <th id="T_97d6b_level0_col0" class="col_heading level0 col0" > Federal-gov</th>
#       <th id="T_97d6b_level0_col1" class="col_heading level0 col1" > Local-gov</th>
#       <th id="T_97d6b_level0_col2" class="col_heading level0 col2" > Never-worked</th>
#       <th id="T_97d6b_level0_col3" class="col_heading level0 col3" > Private</th>
#       <th id="T_97d6b_level0_col4" class="col_heading level0 col4" > Self-emp-inc</th>
#       <th id="T_97d6b_level0_col5" class="col_heading level0 col5" > Self-emp-not-inc</th>
#       <th id="T_97d6b_level0_col6" class="col_heading level0 col6" > State-gov</th>
#       <th id="T_97d6b_level0_col7" class="col_heading level0 col7" > Without-pay</th>
#       <th id="T_97d6b_level0_col8" class="col_heading level0 col8" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Income</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97d6b_level0_row0" class="row_heading level0 row0" > <=50K</th>
#       <td id="T_97d6b_row0_col0" class="data row0 col0" >589</td>
#       <td id="T_97d6b_row0_col1" class="data row0 col1" >1476</td>
#       <td id="T_97d6b_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_97d6b_row0_col3" class="data row0 col3" >19357</td>
#       <td id="T_97d6b_row0_col4" class="data row0 col4" >494</td>
#       <td id="T_97d6b_row0_col5" class="data row0 col5" >1816</td>
#       <td id="T_97d6b_row0_col6" class="data row0 col6" >944</td>
#       <td id="T_97d6b_row0_col7" class="data row0 col7" >14</td>
#       <td id="T_97d6b_row0_col8" class="data row0 col8" >24697</td>
#     </tr>
#     <tr>
#       <th id="T_97d6b_level0_row1" class="row_heading level0 row1" > >50K</th>
#       <td id="T_97d6b_row1_col0" class="data row1 col0" >371</td>
#       <td id="T_97d6b_row1_col1" class="data row1 col1" >617</td>
#       <td id="T_97d6b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_97d6b_row1_col3" class="data row1 col3" >5152</td>
#       <td id="T_97d6b_row1_col4" class="data row1 col4" >622</td>
#       <td id="T_97d6b_row1_col5" class="data row1 col5" >724</td>
#       <td id="T_97d6b_row1_col6" class="data row1 col6" >353</td>
#       <td id="T_97d6b_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_97d6b_row1_col8" class="data row1 col8" >7839</td>
#     </tr>
#     <tr>
#       <th id="T_97d6b_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_97d6b_row2_col0" class="data row2 col0" >960</td>
#       <td id="T_97d6b_row2_col1" class="data row2 col1" >2093</td>
#       <td id="T_97d6b_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_97d6b_row2_col3" class="data row2 col3" >24509</td>
#       <td id="T_97d6b_row2_col4" class="data row2 col4" >1116</td>
#       <td id="T_97d6b_row2_col5" class="data row2 col5" >2540</td>
#       <td id="T_97d6b_row2_col6" class="data row2 col6" >1297</td>
#       <td id="T_97d6b_row2_col7" class="data row2 col7" >14</td>
#       <td id="T_97d6b_row2_col8" class="data row2 col8" >32536</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observation :
#
# 75.3% people belongs to Private sector followed by Self Emplyoed not Incorporated with 7.8 %
#
# Interseting observation comes with Self-Employed Incorporated category where the number of people who earn more than 50K dollars exceed those earning less than it !
#
# There is significant difference between private sector employees income where less than 25 % people earn more than 50K dollars an year.
#
# Another quite surprising insight comes from Federal Goverment countplot where We can see very minute difference between the number of people whose income is more or less than 50K dollars an year. Same goes with state goverment with some difference.
#
# Yes there exist category for who never worked and Working without pay but very few people belong to it.These people may be unempolyeed or colleges students. But Number is less And thats Good !!!

# %%
# Education Vs Income

plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Education'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Education', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(x=df['Education'], hue=df['Income'], palette='hsv')
plt.title('Income distribution as per Education', fontsize=22, fontweight='bold')
p.set_xlabel('Education',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# Observation:
#
# Out of all population 32.3% people with HS-Grad education which is most prevalent education level.
#
# 5.3 % people with masters and 1.3 % population is Doctorate degree holder. Highly educated & intellactual people belongs to this category.
#
# There are very handful people who earn more than 50 K dollars having education below 12th level.
#
# Maximum number of people who earn more than 50K dollars are Bachelors degree holder.
#
# Here comes interesting observation about income of highly educated people. In case of people belonging to Masters, Doctorate and Prof-School category in the education level, the number people earning more than 50K dollars an year outnumber than the number of people earning less than it.
#
# In case of Assoc-acad or Assoc-voc, there are a few people who earn more than 50K dollars an year!

# %%
pd.crosstab(df['Education'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_205c8_row0_col0, #T_205c8_row2_col0, #T_205c8_row2_col1, #T_205c8_row2_col4, #T_205c8_row2_col5, #T_205c8_row2_col6, #T_205c8_row3_col3, #T_205c8_row3_col5, #T_205c8_row4_col5, #T_205c8_row5_col6, #T_205c8_row10_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_205c8_row0_col1, #T_205c8_row1_col1, #T_205c8_row1_col4, #T_205c8_row2_col3, #T_205c8_row2_col8, #T_205c8_row5_col4, #T_205c8_row6_col5, #T_205c8_row6_col8, #T_205c8_row14_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_205c8_row0_col2, #T_205c8_row15_col2 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_205c8_row0_col3, #T_205c8_row7_col3, #T_205c8_row7_col5, #T_205c8_row7_col6, #T_205c8_row14_col0 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_205c8_row0_col4, #T_205c8_row5_col3, #T_205c8_row5_col8, #T_205c8_row6_col3, #T_205c8_row10_col0, #T_205c8_row14_col8 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_205c8_row0_col5, #T_205c8_row0_col8, #T_205c8_row1_col5 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_205c8_row0_col6, #T_205c8_row1_col0, #T_205c8_row1_col6, #T_205c8_row4_col3, #T_205c8_row4_col8, #T_205c8_row5_col1, #T_205c8_row6_col1, #T_205c8_row6_col4, #T_205c8_row10_col1, #T_205c8_row10_col8, #T_205c8_row14_col3 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_205c8_row0_col7, #T_205c8_row1_col7, #T_205c8_row2_col2, #T_205c8_row2_col7, #T_205c8_row3_col0, #T_205c8_row3_col1, #T_205c8_row3_col2, #T_205c8_row3_col4, #T_205c8_row3_col6, #T_205c8_row3_col7, #T_205c8_row3_col8, #T_205c8_row4_col0, #T_205c8_row4_col1, #T_205c8_row4_col2, #T_205c8_row4_col4, #T_205c8_row4_col6, #T_205c8_row4_col7, #T_205c8_row5_col0, #T_205c8_row6_col0, #T_205c8_row6_col2, #T_205c8_row6_col6, #T_205c8_row6_col7, #T_205c8_row7_col2, #T_205c8_row8_col2, #T_205c8_row8_col7, #T_205c8_row9_col2, #T_205c8_row9_col7, #T_205c8_row10_col2, #T_205c8_row10_col7, #T_205c8_row12_col2, #T_205c8_row12_col7, #T_205c8_row13_col0, #T_205c8_row13_col1, #T_205c8_row13_col2, #T_205c8_row13_col3, #T_205c8_row13_col4, #T_205c8_row13_col5, #T_205c8_row13_col6, #T_205c8_row13_col7, #T_205c8_row13_col8, #T_205c8_row14_col2, #T_205c8_row14_col7 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_205c8_row1_col2, #T_205c8_row5_col2, #T_205c8_row11_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_205c8_row1_col3, #T_205c8_row7_col1, #T_205c8_row8_col0, #T_205c8_row8_col1, #T_205c8_row8_col3, #T_205c8_row8_col5, #T_205c8_row8_col8 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_205c8_row1_col8, #T_205c8_row7_col4, #T_205c8_row7_col8, #T_205c8_row8_col4, #T_205c8_row8_col6, #T_205c8_row10_col4 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_205c8_row5_col5, #T_205c8_row12_col3 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_205c8_row5_col7, #T_205c8_row7_col7, #T_205c8_row12_col4, #T_205c8_row14_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_205c8_row7_col0 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_205c8_row9_col0, #T_205c8_row15_col8 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_205c8_row9_col1 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_205c8_row9_col3 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_205c8_row9_col4 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_205c8_row9_col5 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# #T_205c8_row9_col6, #T_205c8_row11_col6 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_205c8_row9_col8, #T_205c8_row12_col1 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_205c8_row10_col5, #T_205c8_row14_col6 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_205c8_row10_col6, #T_205c8_row12_col0 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_205c8_row11_col0 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_205c8_row11_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_205c8_row11_col3 {
#   background-color: #a9d466;
#   color: #000000;
# }
# #T_205c8_row11_col4, #T_205c8_row15_col6 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_205c8_row11_col5 {
#   background-color: #a8d366;
#   color: #000000;
# }
# #T_205c8_row11_col7 {
#   background-color: #5bad66;
#   color: #f1f1f1;
# }
# #T_205c8_row11_col8 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_205c8_row12_col5 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_205c8_row12_col6 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_205c8_row12_col8, #T_205c8_row14_col5 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_205c8_row15_col0 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_205c8_row15_col1 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_205c8_row15_col3 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_205c8_row15_col4 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_205c8_row15_col5 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_205c8_row15_col7 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_205c8_row16_col0, #T_205c8_row16_col1, #T_205c8_row16_col2, #T_205c8_row16_col3, #T_205c8_row16_col4, #T_205c8_row16_col5, #T_205c8_row16_col6, #T_205c8_row16_col7, #T_205c8_row16_col8 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_205c8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Workclass</th>
#       <th id="T_205c8_level0_col0" class="col_heading level0 col0" > Federal-gov</th>
#       <th id="T_205c8_level0_col1" class="col_heading level0 col1" > Local-gov</th>
#       <th id="T_205c8_level0_col2" class="col_heading level0 col2" > Never-worked</th>
#       <th id="T_205c8_level0_col3" class="col_heading level0 col3" > Private</th>
#       <th id="T_205c8_level0_col4" class="col_heading level0 col4" > Self-emp-inc</th>
#       <th id="T_205c8_level0_col5" class="col_heading level0 col5" > Self-emp-not-inc</th>
#       <th id="T_205c8_level0_col6" class="col_heading level0 col6" > State-gov</th>
#       <th id="T_205c8_level0_col7" class="col_heading level0 col7" > Without-pay</th>
#       <th id="T_205c8_level0_col8" class="col_heading level0 col8" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_205c8_level0_row0" class="row_heading level0 row0" > 10th</th>
#       <td id="T_205c8_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_205c8_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_205c8_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_205c8_row0_col3" class="data row0 col3" >795</td>
#       <td id="T_205c8_row0_col4" class="data row0 col4" >19</td>
#       <td id="T_205c8_row0_col5" class="data row0 col5" >67</td>
#       <td id="T_205c8_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_205c8_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_205c8_row0_col8" class="data row0 col8" >933</td>
#     </tr>
#     <tr>
#       <th id="T_205c8_level0_row1" class="row_heading level0 row1" > 11th</th>
#       <td id="T_205c8_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_205c8_row1_col1" class="data row1 col1" >36</td>
#       <td id="T_205c8_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_205c8_row1_col3" class="data row1 col3" >1041</td>
#       <td id="T_205c8_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_205c8_row1_col5" class="data row1 col5" >60</td>
#       <td id="T_205c8_row1_col6" class="data row1 col6" >14</td>
#       <td id="T_205c8_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_205c8_row1_col8" class="data row1 col8" >1175</td>
#     </tr>
#     <tr>
#       <th id="T_205c8_level0_row2" class="row_heading level0 row2" > 12th</th>
#       <td id="T_205c8_row2_col0" class="data row2 col0

# %%
# Percentage Income distribution in terms of Education

sns.set_palette('rainbow')
table = pd.crosstab(df['Education'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,7))
plt.title('Percent Income distribution as per Education', fontsize=22, fontweight='bold')
plt.xlabel('Education', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# Observation:
#
# In terms of percentage 75 % of Doctorate people earn more than 50K dollars an years, followed by Prof- school.
#
# So, Highly earning people most of times comes with Masters or Doctorate education background.
#
# From crosstab we can see that private sector is highest recuriter for HS-Grad with 8305 people.
#
# Private sector is also major recurtier of highly eduacated people with masters, doctorate followed by local goverment.

# %%
# Impact of Marital Status on Income

plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1')
plt.figure(figsize=(10,10))
df['Marital_status'].value_counts().plot.pie(autopct='%2.1f%%', explode=[0.075,0.1,0.125,0.15,0.175,0.2,0.225],
                                             textprops ={'fontsize':13,'fontweight':'bold'},shadow=True)
plt.title('Population distribution as per Marital Status', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# Percentage Income distribution in terms of Education

sns.set_palette('rainbow')
table = pd.crosstab(df['Marital_status'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Marital Status', fontsize=22, fontweight='bold')
plt.xlabel('Marital Status', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# Observation :
#
# Married people are most like to earn more than 50K dollars an year.
#
# Reason Might be Emotional support and stability of life than who are divorced/separated.
#
# One thing to note here is that Married-civ-spouse is the only category which has comparable number of people belonging to both categories.
#
# For others, there are less than 25% of the adults earning more than 50K dollars an year.

# %%
# Occupation VS Income

plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Occupation'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Occupation', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(x=df['Occupation'], hue=df['Income'], palette='cool')
plt.title('Income distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Occupation',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=90)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# Observation :
#
# Exec-managerial role are equally likely to earn more than 50K dollars an year.
#
# Peoples working in Arm- Forces, Farming-fishing, Machine-op-inspect, Other-service, Adm-clerical, Handlers-cleaners are very less likely to earn more than 50K dollars an year.
#
# Around 25% of the people working in Sales earn more than 50K dollars an year.

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(df['Occupation'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Occupation', fontsize=22, fontweight='bold')
plt.xlabel('Occupation', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(df['Occupation'],df["Income"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_4d053_row0_col0 {
#   background-color: #00de90;
#   color: #000000;
# }
# #T_4d053_row0_col1 {
#   background-color: #00ef88;
#   color: #000000;
# }
# #T_4d053_row0_col2 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_4d053_row1_col0, #T_4d053_row1_col1, #T_4d053_row1_col2, #T_4d053_row8_col1 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_4d053_row2_col0, #T_4d053_row2_col2, #T_4d053_row7_col0, #T_4d053_row11_col1 {
#   background-color: #00df90;
#   color: #000000;
# }
# #T_4d053_row2_col1 {
#   background-color: #00e18e;
#   color: #000000;
# }
# #T_4d053_row3_col0 {
#   background-color: #00ea8a;
#   color: #000000;
# }
# #T_4d053_row3_col1 {
#   background-color: #00bfa0;
#   color: #f1f1f1;
# }
# #T_4d053_row3_col2 {
#   background-color: #00e08f;
#   color: #000000;
# }
# #T_4d053_row4_col0, #T_4d053_row12_col1 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_4d053_row4_col1 {
#   background-color: #00fc81;
#   color: #000000;
# }
# #T_4d053_row4_col2, #T_4d053_row12_col2 {
#   background-color: #00f883;
#   color: #000000;
# }
# #T_4d053_row5_col0, #T_4d053_row13_col0 {
#   background-color: #00f286;
#   color: #000000;
# }
# #T_4d053_row5_col1 {
#   background-color: #00fd80;
#   color: #000000;
# }
# #T_4d053_row5_col2, #T_4d053_row13_col1 {
#   background-color: #00f584;
#   color: #000000;
# }
# #T_4d053_row6_col0 {
#   background-color: #00ed88;
#   color: #000000;
# }
# #T_4d053_row6_col1 {
#   background-color: #00f784;
#   color: #000000;
# }
# #T_4d053_row6_col2 {
#   background-color: #00f087;
#   color: #000000;
# }
# #T_4d053_row7_col1, #T_4d053_row10_col0 {
#   background-color: #00fb82;
#   color: #000000;
# }
# #T_4d053_row7_col2 {
#   background-color: #00e68c;
#   color: #000000;
# }
# #T_4d053_row8_col0, #T_4d053_row8_col2 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_4d053_row9_col0 {
#   background-color: #00d793;
#   color: #000000;
# }
# #T_4d053_row9_col1 {
#   background-color: #00bda0;
#   color: #f1f1f1;
# }
# #T_4d053_row9_col2 {
#   background-color: #00d196;
#   color: #000000;
# }
# #T_4d053_row10_col1, #T_4d053_row12_col0 {
#   background-color: #00f982;
#   color: #000000;
# }
# #T_4d053_row10_col2 {
#   background-color: #00fa82;
#   color: #000000;
# }
# #T_4d053_row11_col0 {
#   background-color: #00e48d;
#   color: #000000;
# }
# #T_4d053_row11_col2 {
#   background-color: #00e38e;
#   color: #000000;
# }
# #T_4d053_row13_col2 {
#   background-color: #00f386;
#   color: #000000;
# }
# #T_4d053_row14_col0, #T_4d053_row14_col1, #T_4d053_row14_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d053">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Income</th>
#       <th id="T_4d053_level0_col0" class="col_heading level0 col0" > <=50K</th>
#       <th id="T_4d053_level0_col1" class="col_heading level0 col1" > >50K</th>
#       <th id="T_4d053_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Occupation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d053_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#       <td id="T_4d053_row0_col0" class="data row0 col0" >3260</td>
#       <td id="T_4d053_row0_col1" class="data row0 col1" >507</td>
#       <td id="T_4d053_row0_col2" class="data row0 col2" >3767</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#       <td id="T_4d053_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_4d053_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_4d053_row1_col2" class="data row1 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#       <td id="T_4d053_row2_col0" class="data row2 col0" >3165</td>
#       <td id="T_4d053_row2_col1" class="data row2 col1" >929</td>
#       <td id="T_4d053_row2_col2" class="data row2 col2" >4094</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row3" class="row_heading level0 row3" > Exec-managerial</th>
#       <td id="T_4d053_row3_col0" class="data row3 col0" >2097</td>
#       <td id="T_4d053_row3_col1" class="data row3 col1" >1968</td>
#       <td id="T_4d053_row3_col2" class="data row3 col2" >4065</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row4" class="row_heading level0 row4" > Farming-fishing</th>
#       <td id="T_4d053_row4_col0" class="data row4 col0" >877</td>
#       <td id="T_4d053_row4_col1" class="data row4 col1" >115</td>
#       <td id="T_4d053_row4_col2" class="data row4 col2" >992</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row5" class="row_heading level0 row5" > Handlers-cleaners</th>
#       <td id="T_4d053_row5_col0" class="data row5 col0" >1283</td>
#       <td id="T_4d053_row5_col1" class="data row5 col1" >86</td>
#       <td id="T_4d053_row5_col2" class="data row5 col2" >1369</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row6" class="row_heading level0 row6" > Machine-op-inspct</th>
#       <td id="T_4d053_row6_col0" class="data row6 col0" >1751</td>
#       <td id="T_4d053_row6_col1" class="data row6 col1" >249</td>
#       <td id="T_4d053_row6_col2" class="data row6 col2" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row7" class="row_heading level0 row7" > Other-service</th>
#       <td id="T_4d053_row7_col0" class="data row7 col0" >3154</td>
#       <td id="T_4d053_row7_col1" class="data row7 col1" >137</td>
#       <td id="T_4d053_row7_col2" class="data row7 col2" >3291</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row8" class="row_heading level0 row8" > Priv-house-serv</th>
#       <td id="T_4d053_row8_col0" class="data row8 col0" >146</td>
#       <td id="T_4d053_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_4d053_row8_col2" class="data row8 col2" >147</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row9" class="row_heading level0 row9" > Prof-specialty</th>
#       <td id="T_4d053_row9_col0" class="data row9 col0" >3930</td>
#       <td id="T_4d053_row9_col1" class="data row9 col1" >2049</td>
#       <td id="T_4d053_row9_col2" class="data row9 col2" >5979</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row10" class="row_heading level0 row10" > Protective-serv</th>
#       <td id="T_4d053_row10_col0" class="data row10 col0" >438</td>
#       <td id="T_4d053_row10_col1" class="data row10 col1" >211</td>
#       <td id="T_4d053_row10_col2" class="data row10 col2" >649</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row11" class="row_heading level0 row11" > Sales</th>
#       <td id="T_4d053_row11_col0" class="data row11 col0" >2667</td>
#       <td id="T_4d053_row11_col1" class="data row11 col1" >983</td>
#       <td id="T_4d053_row11_col2" class="data row11 col2" >3650</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row12" class="row_heading level0 row12" > Tech-support</th>
#       <td id="T_4d053_row12_col0" class="data row12 col0" >644</td>
#       <td id="T_4d053_row12_col1" class="data row12 col1" >283</td>
#       <td id="T_4d053_row12_col2" class="data row12 col2" >927</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row13" class="row_heading level0 row13" > Transport-moving</th>
#       <td id="T_4d053_row13_col0" class="data row13 col0" >1277</td>
#       <td id="T_4d053_row13_col1" class="data row13 col1" >320</td>
#       <td id="T_4d053_row13_col2" class="data row13 col2" >1597</td>
#     </tr>
#     <tr>
#       <th id="T_4d053_level0_row14" class="row_heading level0 row14" >All</th>
#       <td id="T_4d053_row14_col0" class="data row14 col0" >24697</td>
#       <td id="T_4d053_row14_col1" class="data row14 col1" >7839</td>
#       <td id="T_4d053_row14_col2" class="data row14 col2" >32536</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observation :
#
# Prof-Speciality position with maximum 2049 peoples followed by Exec-managerial position with 1968 people leads chart for greater than 50K dollars an year.
#
# If we talk in term of percentage probablity Exective Managerial position have 50% chances to lead in Greater than 50K dollars Club.
#
# There's close to 33% probablity for an adult in Prof-specialty to earn more than 50K dollars an year.
#
# - Minimum chances for Greater than 50K Club comes from Private House Service occupation where 1/147 chance of getting more than 50K dollars an year.

# %%
pd.crosstab(df['Occupation'],df["Workclass"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_a6e63_row0_col0 {
#   background-color: #00abaa;
#   color: #f1f1f1;
# }
# #T_a6e63_row0_col1 {
#   background-color: #00dd90;
#   color: #000000;
# }
# #T_a6e63_row0_col2, #T_a6e63_row1_col1, #T_a6e63_row1_col2, #T_a6e63_row1_col3, #T_a6e63_row1_col4, #T_a6e63_row1_col5, #T_a6e63_row1_col6, #T_a6e63_row1_col7, #T_a6e63_row1_col8, #T_a6e63_row2_col2, #T_a6e63_row3_col2, #T_a6e63_row3_col7, #T_a6e63_row4_col2, #T_a6e63_row5_col2, #T_a6e63_row5_col4, #T_a6e63_row6_col2, #T_a6e63_row7_col2, #T_a6e63_row8_col0, #T_a6e63_row8_col1, #T_a6e63_row8_col2, #T_a6e63_row8_col4, #T_a6e63_row8_col5, #T_a6e63_row8_col6, #T_a6e63_row8_col7, #T_a6e63_row9_col7, #T_a6e63_row10_col2, #T_a6e63_row10_col5, #T_a6e63_row10_col7, #T_a6e63_row11_col1, #T_a6e63_row11_col2, #T_a6e63_row11_col7, #T_a6e63_row12_col2, #T_a6e63_row12_col4, #T_a6e63_row12_col7, #T_a6e63_row13_col2 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_a6e63_row0_col3, #T_a6e63_row0_col8 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_a6e63_row0_col4, #T_a6e63_row4_col8, #T_a6e63_row10_col0, #T_a6e63_row12_col3, #T_a6e63_row12_col8 {
#   background-color: #00f883;
#   color: #000000;
# }
# #T_a6e63_row0_col5, #T_a6e63_row5_col1, #T_a6e63_row10_col8 {
#   background-color: #00fa82;
#   color: #000000;
# }
# #T_a6e63_row0_col6 {
#   background-color: #00ce98;
#   color: #000000;
# }
# #T_a6e63_row0_col7 {
#   background-color: #00c99a;
#   color: #000000;
# }
# #T_a6e63_row1_col0, #T_a6e63_row4_col0, #T_a6e63_row4_col6, #T_a6e63_row6_col4, #T_a6e63_row6_col6, #T_a6e63_row11_col6, #T_a6e63_row12_col5 {
#   background-color: #00fd80;
#   color: #000000;
# }
# #T_a6e63_row2_col0, #T_a6e63_row2_col1, #T_a6e63_row7_col5 {
#   background-color: #00ee88;
#   color: #000000;
# }
# #T_a6e63_row2_col3 {
#   background-color: #00de90;
#   color: #000000;
# }
# #T_a6e63_row2_col4, #T_a6e63_row7_col6 {
#   background-color: #00e78c;
#   color: #000000;
# }
# #T_a6e63_row2_col5 {
#   background-color: #00ca9a;
#   color: #000000;
# }
# #T_a6e63_row2_col6, #T_a6e63_row4_col4, #T_a6e63_row12_col6 {
#   background-color: #00f485;
#   color: #000000;
# }
# #T_a6e63_row2_col7, #T_a6e63_row5_col7, #T_a6e63_row6_col7, #T_a6e63_row7_col7, #T_a6e63_row12_col0, #T_a6e63_row13_col7 {
#   background-color: #00ed88;
#   color: #000000;
# }
# #T_a6e63_row2_col8 {
#   background-color: #00df90;
#   color: #000000;
# }
# #T_a6e63_row3_col0 {
#   background-color: #00cf98;
#   color: #000000;
# }
# #T_a6e63_row3_col1 {
#   background-color: #00e58c;
#   color: #000000;
# }
# #T_a6e63_row3_col3, #T_a6e63_row7_col3, #T_a6e63_row11_col8 {
#   background-color: #00e38e;
#   color: #000000;
# }
# #T_a6e63_row3_col4 {
#   background-color: #00a4ad;
#   color: #f1f1f1;
# }
# #T_a6e63_row3_col5 {
#   background-color: #00d893;
#   color: #000000;
# }
# #T_a6e63_row3_col6, #T_a6e63_row9_col5, #T_a6e63_row10_col1 {
#   background-color: #00da92;
#   color: #000000;
# }
# #T_a6e63_row3_col8 {
#   background-color: #00e08f;
#   color: #000000;
# }
# #T_a6e63_row4_col1, #T_a6e63_row6_col0, #T_a6e63_row6_col5, #T_a6e63_row11_col0 {
#   background-color: #00fc81;
#   color: #000000;
# }
# #T_a6e63_row4_col3, #T_a6e63_row12_col1 {
#   background-color: #00fb82;
#   color: #000000;
# }
# #T_a6e63_row4_col5, #T_a6e63_row9_col3 {
#   background-color: #00d495;
#   color: #000000;
# }
# #T_a6e63_row4_col7 {
#   background-color: #0092b6;
#   color: #f1f1f1;
# }
# #T_a6e63_row5_col0, #T_a6e63_row7_col4, #T_a6e63_row13_col0, #T_a6e63_row13_col4 {
#   background-color: #00f982;
#   color: #000000;
# }
# #T_a6e63_row5_col3, #T_a6e63_row13_col3 {
#   background-color: #00f286;
#   color: #000000;
# }
# #T_a6e63_row5_col5, #T_a6e63_row5_col6, #T_a6e63_row6_col1, #T_a6e63_row8_col3, #T_a6e63_row8_col8, #T_a6e63_row10_col3, #T_a6e63_row10_col4 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_a6e63_row5_col8 {
#   background-color: #00f584;
#   color: #000000;
# }
# #T_a6e63_row6_col3 {
#   background-color: #00ec89;
#   color: #000000;
# }
# #T_a6e63_row6_col8 {
#   background-color: #00f087;
#   color: #000000;
# }
# #T_a6e63_row7_col0 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_a6e63_row7_col1 {
#   background-color: #00e88b;
#   color: #000000;
# }
# #T_a6e63_row7_col8 {
#   background-color: #00e68c;
#   color: #000000;
# }
# #T_a6e63_row9_col0, #T_a6e63_row9_col8 {
#   background-color: #00d196;
#   color: #000000;
# }
# #T_a6e63_row9_col1 {
#   background-color: #00a9ab;
#   color: #f1f1f1;
# }
# #T_a6e63_row9_col2, #T_a6e63_row14_col0, #T_a6e63_row14_col1, #T_a6e63_row14_col2, #T_a6e63_row14_col3, #T_a6e63_row14_col4, #T_a6e63_row14_col5, #T_a6e63_row14_col6, #T_a6e63_row14_col7, #T_a6e63_row14_col8 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_a6e63_row9_col4 {
#   background-color: #00db92;
#   color: #000000;
# }
# #T_a6e63_row9_col6 {
#   background-color: #00aea8;
#   color: #f1f1f1;
# }
# #T_a6e63_row10_col6 {
#   background-color: #00e98a;
#   color: #000000;
# }
# #T_a6e63_row11_col3 {
#   background-color: #00e18e;
#   color: #000000;
# }
# #T_a6e63_row11_col4 {
#   background-color: #00bda0;
#   color: #f1f1f1;
# }
# #T_a6e63_row11_col5 {
#   background-color: #00d992;
#   color: #000000;
# }
# #T_a6e63_row13_col1 {
#   background-color: #00f186;
#   color: #000000;
# }
# #T_a6e63_row13_col5, #T_a6e63_row13_col8 {
#   background-color: #00f386;
#   color: #000000;
# }
# #T_a6e63_row13_col6 {
#   background-color: #00f784;
#   color: #000000;
# }
# </style>
# <table id="T_a6e63">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Workclass</th>
#       <th id="T_a6e63_level0_col0" class="col_heading level0 col0" > Federal-gov</th>
#       <th id="T_a6e63_level0_col1" class="col_heading level0 col1" > Local-gov</th>
#       <th id="T_a6e63_level0_col2" class="col_heading level0 col2" > Never-worked</th>
#       <th id="T_a6e63_level0_col3" class="col_heading level0 col3" > Private</th>
#       <th id="T_a6e63_level0_col4" class="col_heading level0 col4" > Self-emp-inc</th>
#       <th id="T_a6e63_level0_col5" class="col_heading level0 col5" > Self-emp-not-inc</th>
#       <th id="T_a6e63_level0_col6" class="col_heading level0 col6" > State-gov</th>
#       <th id="T_a6e63_level0_col7" class="col_heading level0 col7" > Without-pay</th>
#       <th id="T_a6e63_level0_col8" class="col_heading level0 col8" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Occupation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6e63_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#       <td id="T_a6e63_row0_col0" class="data row0 col0" >317</td>
#       <td id="T_a6e63_row0_col1" class="data row0 col1" >283</td>
#       <td id="T_a6e63_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a6e63_row0_col3" class="data row0 col3" >2831</td>
#       <td id="T_a6e63_row0_col4" class="data row0 col4" >31</td>
#       <td id="T_a6e63_row0_col5" class="data row0 col5" >50</td>
#       <td id="T_a6e63_row0_col6" class="data row0 col6" >252</td>
#       <td id="T_a6e63_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_a6e63_row0_col8" class="data row0 col8" >3767</td>
#     </tr>
#     <tr>
#       <th id="T_a6e63_level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#       <td id="T_a6e63_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_a6e63_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_a6e63_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_a6e63_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_a6e63_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_a6e63_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_a6e63_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_a6e63_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_a6e63_row1_col8" class="data row1 col8" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a6e63_level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#       <td i

# %% [markdown]
# Observation :
#
# Here is another surprising element, there are 7 peoples From Never Worked Category with High earning Profession of Prof-speciality. Same from Without pay workclass we find 6 peoples with Exec-Managerial. Possibly they are working with unpaid internship profile.

# %%
# Sex Vs Income
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Sex'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Sex',hue=df['Income'] ,data=df,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Observation:
#
# Significant gap between male and female earnings.
#
# Less than 10% Women in Greater Than 50K Dollar Club.
#
# Around 33% of Men earning more than 50K dollars an year.

# %%
pd.crosstab(df['Occupation'],[df.Sex,df.Income], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_f2335_row0_col0 {
#   background-color: #00c19e;
#   color: #f1f1f1;
# }
# #T_f2335_row0_col1, #T_f2335_row7_col0, #T_f2335_row9_col4 {
#   background-color: #00d196;
#   color: #000000;
# }
# #T_f2335_row0_col2, #T_f2335_row6_col4 {
#   background-color: #00f087;
#   color: #000000;
# }
# #T_f2335_row0_col3, #T_f2335_row7_col1, #T_f2335_row13_col3 {
#   background-color: #00f485;
#   color: #000000;
# }
# #T_f2335_row0_col4 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_f2335_row1_col0, #T_f2335_row1_col1, #T_f2335_row1_col2, #T_f2335_row1_col3, #T_f2335_row1_col4, #T_f2335_row4_col1, #T_f2335_row5_col1, #T_f2335_row8_col1, #T_f2335_row8_col2, #T_f2335_row8_col3 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_f2335_row2_col0, #T_f2335_row10_col4, #T_f2335_row12_col2 {
#   background-color: #00fa82;
#   color: #000000;
# }
# #T_f2335_row2_col1, #T_f2335_row4_col3, #T_f2335_row5_col0, #T_f2335_row6_col1 {
#   background-color: #00fb82;
#   color: #000000;
# }
# #T_f2335_row2_col2 {
#   background-color: #00cd98;
#   color: #000000;
# }
# #T_f2335_row2_col3, #T_f2335_row11_col3 {
#   background-color: #00dd90;
#   color: #000000;
# }
# #T_f2335_row2_col4 {
#   background-color: #00df90;
#   color: #000000;
# }
# #T_f2335_row3_col0, #T_f2335_row7_col2 {
#   background-color: #00e88b;
#   color: #000000;
# }
# #T_f2335_row3_col1 {
#   background-color: #00c39e;
#   color: #000000;
# }
# #T_f2335_row3_col2, #T_f2335_row6_col2, #T_f2335_row13_col2 {
#   background-color: #00eb8a;
#   color: #000000;
# }
# #T_f2335_row3_col3 {
#   background-color: #00bfa0;
#   color: #f1f1f1;
# }
# #T_f2335_row3_col4, #T_f2335_row11_col0 {
#   background-color: #00e08f;
#   color: #000000;
# }
# #T_f2335_row4_col0, #T_f2335_row8_col4, #T_f2335_row10_col0, #T_f2335_row13_col1 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_f2335_row4_col2 {
#   background-color: #00f286;
#   color: #000000;
# }
# #T_f2335_row4_col4, #T_f2335_row10_col3, #T_f2335_row12_col4 {
#   background-color: #00f883;
#   color: #000000;
# }
# #T_f2335_row5_col2 {
#   background-color: #00ed88;
#   color: #000000;
# }
# #T_f2335_row5_col3, #T_f2335_row7_col3, #T_f2335_row8_col0 {
#   background-color: #00fc81;
#   color: #000000;
# }
# #T_f2335_row5_col4 {
#   background-color: #00f584;
#   color: #000000;
# }
# #T_f2335_row6_col0 {
#   background-color: #00f186;
#   color: #000000;
# }
# #T_f2335_row6_col3, #T_f2335_row12_col0 {
#   background-color: #00f784;
#   color: #000000;
# }
# #T_f2335_row7_col4, #T_f2335_row11_col2 {
#   background-color: #00e68c;
#   color: #000000;
# }
# #T_f2335_row9_col0 {
#   background-color: #00cc99;
#   color: #000000;
# }
# #T_f2335_row9_col1 {
#   background-color: #00a1ae;
#   color: #f1f1f1;
# }
# #T_f2335_row9_col2 {
#   background-color: #00de90;
#   color: #000000;
# }
# #T_f2335_row9_col3 {
#   background-color: #00c29e;
#   color: #000000;
# }
# #T_f2335_row10_col1, #T_f2335_row13_col0 {
#   background-color: #00fd80;
#   color: #000000;
# }
# #T_f2335_row10_col2 {
#   background-color: #00f982;
#   color: #000000;
# }
# #T_f2335_row11_col1 {
#   background-color: #00ec89;
#   color: #000000;
# }
# #T_f2335_row11_col4 {
#   background-color: #00e38e;
#   color: #000000;
# }
# #T_f2335_row12_col1, #T_f2335_row12_col3 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_f2335_row13_col4 {
#   background-color: #00f386;
#   color: #000000;
# }
# #T_f2335_row14_col0, #T_f2335_row14_col1, #T_f2335_row14_col2, #T_f2335_row14_col3, #T_f2335_row14_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2335">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_f2335_level0_col0" class="col_heading level0 col0" colspan="2"> Female</th>
#       <th id="T_f2335_level0_col2" class="col_heading level0 col2" colspan="2"> Male</th>
#       <th id="T_f2335_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Income</th>
#       <th id="T_f2335_level1_col0" class="col_heading level1 col0" > <=50K</th>
#       <th id="T_f2335_level1_col1" class="col_heading level1 col1" > >50K</th>
#       <th id="T_f2335_level1_col2" class="col_heading level1 col2" > <=50K</th>
#       <th id="T_f2335_level1_col3" class="col_heading level1 col3" > >50K</th>
#       <th id="T_f2335_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Occupation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2335_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#       <td id="T_f2335_row0_col0" class="data row0 col0" >2323</td>
#       <td id="T_f2335_row0_col1" class="data row0 col1" >212</td>
#       <td id="T_f2335_row0_col2" class="data row0 col2" >937</td>
#       <td id="T_f2335_row0_col3" class="data row0 col3" >295</td>
#       <td id="T_f2335_row0_col4" class="data row0 col4" >3767</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#       <td id="T_f2335_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f2335_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f2335_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_f2335_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_f2335_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#       <td id="T_f2335_row2_col0" class="data row2 col0" >202</td>
#       <td id="T_f2335_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_f2335_row2_col2" class="data row2 col2" >2963</td>
#       <td id="T_f2335_row2_col3" class="data row2 col3" >909</td>
#       <td id="T_f2335_row2_col4" class="data row2 col4" >4094</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row3" class="row_heading level0 row3" > Exec-managerial</th>
#       <td id="T_f2335_row3_col0" class="data row3 col0" >879</td>
#       <td id="T_f2335_row3_col1" class="data row3 col1" >280</td>
#       <td id="T_f2335_row3_col2" class="data row3 col2" >1218</td>
#       <td id="T_f2335_row3_col3" class="data row3 col3" >1688</td>
#       <td id="T_f2335_row3_col4" class="data row3 col4" >4065</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row4" class="row_heading level0 row4" > Farming-fishing</th>
#       <td id="T_f2335_row4_col0" class="data row4 col0" >63</td>
#       <td id="T_f2335_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_f2335_row4_col2" class="data row4 col2" >814</td>
#       <td id="T_f2335_row4_col3" class="data row4 col3" >113</td>
#       <td id="T_f2335_row4_col4" class="data row4 col4" >992</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row5" class="row_heading level0 row5" > Handlers-cleaners</th>
#       <td id="T_f2335_row5_col0" class="data row5 col0" >160</td>
#       <td id="T_f2335_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_f2335_row5_col2" class="data row5 col2" >1123</td>
#       <td id="T_f2335_row5_col3" class="data row5 col3" >82</td>
#       <td id="T_f2335_row5_col4" class="data row5 col4" >1369</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row6" class="row_heading level0 row6" > Machine-op-inspct</th>
#       <td id="T_f2335_row6_col0" class="data row6 col0" >529</td>
#       <td id="T_f2335_row6_col1" class="data row6 col1" >20</td>
#       <td id="T_f2335_row6_col2" class="data row6 col2" >1222</td>
#       <td id="T_f2335_row6_col3" class="data row6 col3" >229</td>
#       <td id="T_f2335_row6_col4" class="data row6 col4" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_f2335_level0_row7" class="row_heading level0 row7" > Other-service</th>
#       <td id="T_f2335_row7_col0" class="data row7 col0" >1748</td>
#       <td id="T_f2335_row7_col1" class="data row7 col1" >51</td>
#       <td id="T_f2335_row7_col2" class="data row7 col2" >1406</td>
#       <td id="T_f2335_row7_col3" class="data row7 col3" >86</td>
#       <td id="T_f2335_row7_col4" class="data row7 col4" >3291</td>
#     </tr>
#     <tr>
#       <th id="T_

# %% [markdown]
# Observation:
#
# Out of all population 33 % are womens. Inside that most of females work in Adm-clerical,Other-service,Prof-specialty.
#
# Same as in case of Men Maximum number in Greater than 50K dollars Club in females comes from Prof-speciality,Exec-Managerial profession.
#
# Maximum men work in Prof-Specialty.

# %%
# This shows the hours per week according to the education of the person
sns.set(rc={'figure.figsize':(12,8)})
sns_grad = sns.barplot(x = df['Education'], y = df['Hours_per_week'], data = df)
plt.setp(sns_grad.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Encoding categorical data

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          9             13               2
# 1   38          3  215646         11              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          9             13               2
# 4   37          3  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income age_group
# 0              13              38       0     41-50
# 1              40              38       0     31-40
# 2              40              38       0     51-60
# 3              40               4       0     19-30
# 4              40              38       0     31-40

# %% [markdown]
# #### Feature selection and Engineering

# %%
# Outliers Detection and Removal

plt.figure(figsize=(18,10),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# Droping unnecessary columns
df.drop(["Fnlwgt", "Education","age_group"], axis=1, inplace=True)

# %%
from scipy.stats import zscore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32536 entries, 0 to 32559
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32536 non-null  int64
#  1   Workclass       32536 non-null  int32
#  2   Education_num   32536 non-null  int64
#  3   Marital_status  32536 non-null  int32
#  4   Occupation      32536 non-null  int32
#  5   Relationship    32536 non-null  int32
#  6   Race            32536 non-null  int32
#  7   Sex             32536 non-null  int32
#  8   Capital_gain    32536 non-null  int64
#  9   Capital_loss    32536 non-null  int64
#  10  Hours_per_week  32536 non-null  int64
#  11  Native_country  32536 non-null  int32
#  12  Income          32536 non-null  int32
# dtypes: int32(8), int64(5)
# memory usage: 3.5 MB

# %%
# Outliers removal using Zscore method

z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (32536, 13)
# Shape of the dataframe after removing outliers:  (28061, 13)
# Percentage of data loss post outlier removal:  13.753995574133269

# %%
# Data Loss

print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((32536-28061)/32536)*100,'%')
# Out:
# Percentage Data Loss : 13.753995574133269 %

# %% [markdown]
# We are losing 13.75 % of data. Its big but we can afford it. Considering we have a lot of rows in our datatset for ML model building. We have option to go for quantile method but by looking at boxplot we can say lower capping will result in useful data loss and eventually data loss will be more than zscore method.

# %%
# Skewness of features

plt.figure(figsize=(22,5),facecolor='white')
plotnum=1
for col in df[['Age','Capital_gain','Capital_loss','Hours_per_week']]:
    if plotnum<=4:
        plt.subplot(1,4,plotnum)
        sns.distplot(df[col],color='r')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df.skew()
# Out:
# Age                0.487918
# Workclass          0.080746
# Education_num     -0.147601
# Marital_status    -0.046623
# Occupation         0.015247
# Relationship       0.752334
# Race              -2.549199
# Sex               -0.689977
# Capital_gain       4.924729
# Capital_loss      29.669292
# Hours_per_week    -0.359365
# Native_country    -5.348195
# Income             1.322011
# dtype: float64

# %% [markdown]
# Observation :
#
# Relationship,Sex,Native_country,Income are skewed but as they are categorical concept of skewness doesnot mean anything to it.
#
# Capital_gain and Capital_loss are numeric variable with lot of zero and high number. So skewness exist in them. There is no
#
# point in transforming it because at end data will be skewed.

# %%
# Corrleation

df.corr()
# Out:
#                      Age  Workclass  Education_num  Marital_status  \
# Age             1.000000   0.029674       0.045622       -0.286328
# Workclass       0.029674   1.000000      -0.002200       -0.015623
# Education_num   0.045622  -0.002200       1.000000       -0.058587
# Marital_status -0.286328  -0.015623      -0.058587        1.000000
# Occupation     -0.001610   0.008779       0.073142        0.036477
# Relationship   -0.270591  -0.057823      -0.092447        0.183248
# Race            0.021292   0.067532       0.080766       -0.084558
# Sex             0.089469   0.069617       0.003688       -0.125361
# Capital_gain    0.131998   0.011083       0.157858       -0.069601
# Capital_loss    0.023459  -0.010613       0.007348       -0.016396
# Hours_per_week  0.090783   0.028104       0.156303       -0.196053
# Native_country  0.037494   0.001938       0.149688       -0.032575
# Income          0.241844  -0.007699       0.320271       -0.194146
#
#                 Occupation  Relationship      Race       Sex  Capital_gain  \
# Age              -0.001610     -0.270591  0.021292  0.089469      0.131998
# Workclass         0.008779     -0.057823  0.067532  0.069617      0.011083
# Education_num     0.073142     -0.092447  0.080766  0.003688      0.157858
# Marital_status    0.036477      0.183248 -0.084558 -0.125361     -0.069601
# Occupation        1.000000     -0.038735  0.000613  0.051055      0.009446
# Relationship     -0.038735      1.000000 -0.146432 -0.577195     -0.089095
# Race              0.000613     -0.146432  1.000000  0.122731      0.031333
# Sex               0.051055     -0.577195  0.122731  1.000000      0.069539
# Capital_gain      0.009446     -0.089095  0.031333  0.069539      1.000000
# Capital_loss     -0.004779      0.030105  0.000186 -0.027323     -0.009077
# Hours_per_week   -0.022194     -0.261919  0.055486  0.236168      0.098705
# Native_country    0.018069     -0.011274  0.018660 -0.011189      0.019185
# Income            0.030664     -0.248263  0.094756  0.211792      0.343487
#
#                 Capital_loss  Hours_per_week  Native_country    Income
# Age                 0.023459        0.090783        0.037494  0.241844
# Workclass          -0.010613        0.028104        0.001938 -0.007699
# Education_num       0.007348        0.156303        0.149688  0.320271
# Marital_status     -0.016396       -0.196053       -0.032575 -0.194146
# Occupation         -0.004779       -0.022194        0.018069  0.030664
# Relationship        0.030105       -0.261919       -0.011274 -0.248263
# Race                0.000186        0.055486        0.018660  0.094756
# Sex                -0.027323        0.236168       -0.011189  0.211792
# Capital_gain       -0.009077        0.098705        0.019185  0.343487
# Capital_loss        1.000000       -0.003440        0.002925 -0.016465
# Hours_per_week     -0.003440        1.000000        0.004380  0.233472
# Native_country      0.002925        0.004380        1.000000  0.047240
# Income             -0.016465        0.233472        0.047240  1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Income'].drop(['Income']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Income',fontsize = 18)
plt.show()

# %% [markdown]
# Observation:
#
# Capital loss and workclass,occupation, native country, race are correlated with target variable with less than 10% correlation. After checking Mulitcollinearity we will decide to drop these poorly correlated features or go for PCA.
#
#
# As high or low Correlation doesnot mean its causation !!!
#
#
# Between input features maximum correlation of -0.557 exist between sex and relationship.
#
#
# Capital gain is highly correlated with target variable.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Checking Multicollinearity between features using variance_inflation_factor


vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#           VIF        Features
# 0   10.452897             Age
# 1    8.807425       Workclass
# 2   21.287850   Education_num
# 3    4.358505  Marital_status
# 4    3.357557      Occupation
# 5    2.937270    Relationship
# 6   36.291318            Race
# 7    4.566872             Sex
# 8    1.209589    Capital_gain
# 9    1.004295    Capital_loss
# 10  15.202917  Hours_per_week
# 11  79.077624  Native_country
# 12   1.777448          Income

# %% [markdown]
# Strategy to Address Multicollinearity :
#
# Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
#
# Another way to address Multicollinerity is to Scaled Data and then apply PCA.

# %%
# Balanceing Imbalanced target feature

df.Income.value_counts()
# Out:
# 0    21767
# 1     6294
# Name: Income, dtype: int64

# %% [markdown]
# As Target variable data is Imbalanced in nature we will need to balance target variable.

# %%
# Balancing using SMOTE

from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = df.drop(['Income'], axis =1)
Y = df['Income']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 0    21767
# 1    21767
# Name: Income, dtype: int64

# %% [markdown]
# We have successfully resolved the class imbalanced problem and now all the categories have same data ensuring that the ML model does not get biased towards one category.

# %% [markdown]
# #### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(5,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=9)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(9))

# %% [markdown]
# #### Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (30473, 9)
# Training target vector size: (30473,)
# Test feature matrix size: (13061, 9)
# Test target vector size: (13061,)

# %%
# Finding best Random state

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.7764336574534875 on Random_state 120

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=120, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7764336574534875
#
#
# Confusion matrix of Logistics Regression :
#  [[4942 1589]
#  [1331 5199]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77      6531
#            1       0.77      0.80      0.78      6530
#
#     accuracy                           0.78     13061
#    macro avg       0.78      0.78      0.78     13061
# weighted avg       0.78      0.78      0.78     13061

# %%
# Finding Optimal value of n_neighbors for KNN

from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(12):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.3980082099417968
# RMSE value for k=  2 is: 0.42363378591034817
# RMSE value for k=  3 is: 0.3918040976825994
# RMSE value for k=  4 is: 0.4048742149468099
# RMSE value for k=  5 is: 0.3936561487691346
# RMSE value for k=  6 is: 0.3963697141685821
# RMSE value for k=  7 is: 0.39433629071559106
# RMSE value for k=  8 is: 0.39326696810180317
# RMSE value for k=  9 is: 0.3955963091113955
# RMSE value for k=  10 is: 0.39501526158734074
# RMSE value for k=  11 is: 0.3964662837190876
# RMSE value for k=  12 is: 0.39501526158734074

# %% [markdown]
# Comment-
#
# At k=3, we get the minimum RMSE value which approximately 0.3918040976825994, and shoots up on further increasing the k value. We can safely say that k=3 will give us the best result in this case

# %% [markdown]
# #### Applying other classification algorithm

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.7764336574534875
#
#
# Confusion matrix :
#  [[4942 1589]
#  [1331 5199]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77      6531
#            1       0.77      0.80      0.78      6530
#
#     accuracy                           0.78     13061
#    macro avg       0.78      0.78      0.78     13061
# weighted avg       0.78      0.78      0.78     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8271954674220963
#
#
# Confusion matrix :
#  [[4907 1624]
#  [ 633 5897]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81      6531
#            1       0.78      0.90      0.84      6530
#
#     accuracy                           0.83     13061
#    macro avg       0.83      0.83      0.83     13061
# weighted avg       0.83      0.83      0.83     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.7314141336804226
#
#
# Confusion matrix :
#  [[3993 2538]
#  [ 970 5560]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.61      0.69      6531
#            1       0.69      0.85      0.76      6530
#
#     accuracy                           0.73     13061
#    macro avg       0.75      0.73      0.73     13061
# weighted avg       0.75      0.73      0.73     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.8186203200367507
#
#
# Confusion matrix :
#  [[5259 1272]
#  [1097 5433]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      6531
#            1       0.81      0.83      0.82      6530
#
#     accuracy                           0.82     13061
#    macro avg       0.82      0.82      0.82     13061
# weighted avg       0.82      0.82      0.82     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.8464895490391241
#
#
# Confusion matrix :
#  [[5268 1263]
#  [ 742 5788]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84      6531
#            1       0.82      0.89      0.85      6530
#
#     accuracy                           0.85     13061
#    macro avg       0.85      0.85      0.85     13061
# weighted avg       0.85      0.85      0.85     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8569787918229844
#
#
# Confusion matrix :
#  [[5448 1083]
#  [ 785 5745]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      6531
#            1       0.84      0.88      0.86      6530
#
#     accuracy                           0.86     13061
#    macro avg       0.86      0.86      0.86     13061
# weighted avg       0.86      0.86      0.86     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.8567491003751627
#
#
# Confusion matrix :
#  [[5512 1019]
#  [ 852 5678]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      6531
#            1       0.85      0.87      0.86      6530
#
#     accuracy                           0.86     13061
#    macro avg       0.86      0.86      0.86     13061
# weighted avg       0.86      0.86      0.86     13061
#
#
#
# ============================================================================================================

# %% [markdown]
# #### CrossValidation :

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.7612266  0.76857701 0.76742851 0.77317101 0.77130714]
# Mean Score : 0.7683420536842653
# Std deviation : 0.00408974484215439
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.8132537  0.82037441 0.82611692 0.82738027 0.83023202]
# Mean Score : 0.8234714650746271
# Std deviation : 0.006032855118489882
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.710348   0.72481911 0.73504077 0.72596761 0.73121985]
# Mean Score : 0.7254790678729386
# Std deviation : 0.008414348476296235
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.78936488 0.8127943  0.82232686 0.83231882 0.82827935]
# Mean Score : 0.8170168434442994
# Std deviation : 0.015307853602911143
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.80992305 0.84265533 0.84828299 0.8549443  0.853779  ]
# Mean Score : 0.8419169353164806
# Std deviation : 0.016583735318478798
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.82898817 0.85276215 0.86596991 0.86987481 0.87066391]
# Mean Score : 0.8576517896843907
# Std deviation : 0.015706179578000638
#
#
# ============================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.82795452 0.85172849 0.86528081 0.87010451 0.87135309]
# Mean Score : 0.8572842851289726
# Std deviation : 0.016231672018918602
#
#
# ============================================================================================================

# %% [markdown]
# #### Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
              'min_samples_split':[3,5,8],
              'max_depth' : [20,30,40],
              'n_estimators' : [100, 150, 200]}

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.851 total time=   3.0s
# [CV 2/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.850 total time=   3.0s
# [CV 3/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.853 total time=   2.9s
# [CV 4/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.848 total time=   2.9s
# [CV 5/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.851 total time=   2.9s
# [CV 1/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 1/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.850 total time=   4.4s
# [CV 2/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 2/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.849 total time=   4.4s
# [CV 3/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 3/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.850 total time=   4.4s
# [CV 4/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 4/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.843 total time=   4.3s
# [CV 5/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 5/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.848 total time=   4.4s
# [CV 1/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 1/5; 3/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.851 total time=   5.9s
# [CV 2/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 2/5; 3/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.849 total time=   5.9s
# [CV 3/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 3/5; 3/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.852 total time=   5.8s
# [CV 4/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 4/5; 3/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.846 total time=   5.9s
# [CV 5/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 5/5; 3/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.848 total time=   5.9s
# [CV 1/5; 4/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 1/5; 4/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.850 total time=   2.8s
# [CV 2/5; 4/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 2/5; 4/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.847 total time=   2.8s
# [CV 3/5; 4/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 3/5; 4/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.852 total time=   2.8s
# [CV 4/5; 4/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 4/5; 4/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.845 total time=   2.9s
# [CV 5/5; 4/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 5/5; 4/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.847 total time=   2.9s
# [CV 1/5; 5/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 1/5; 5/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.847 total time=   4.2s
# [CV 2/5; 5/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 2/5; 5/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.847 total time=   4.3s
# [CV 3/5; 5/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 3/5; 5/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.853 total time=   4.3s
# [CV 4/5; 5/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 4/5; 5/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.845 total time=   4.3s
# [CV 5/5; 5/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 5/5; 5/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.847 total time=   4.3s
# [CV 1/5; 6/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.849 total time=   5.8s
# [CV 2/5; 6/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.847 total time=   5.8s
# [CV 3/5; 6/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 3/5; 6/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.849 total time=   5.8s
# [CV 4/5; 6/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 4/5; 6/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.845 total time=   5.7s
# [CV 5/5; 6/54] START criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 5/5; 6/54] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.846 total time=   5.7s
# [CV 1/5; 7/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 1/5; 7/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.847 total time=   2.7s
# [CV 2/5; 7/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 2/5; 7/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.844 total time=   2.7s
# [CV 3/5; 7/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 3/5; 7/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.847 total time=   2.8s
# [CV 4/5; 7/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 4/5; 7/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.839 total time=   2.7s
# [CV 5/5; 7/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 5/5; 7/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.843 total time=   2.7s
# [CV 1/5; 8/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 1/5; 8/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.846 total time=   4.2s
# [CV 2/5; 8/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 2/5; 8/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.845 total time=   4.2s
# [CV 3/5; 8/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 3/5; 8/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.849 total time=   4.2s
# [CV 4/5; 8/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 4/5; 8/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.841 total time=   4.1s
# [CV 5/5; 8/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 5/5; 8/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.847 total time=   4.2s
# [CV 1/5; 9/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 1/5; 9/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.847 total time=   5.6s
# [CV 2/5; 9/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 2/5; 9/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.844 total time=   5.6s
# [CV 3/5; 9/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 3/5; 9/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.849 total time=   5.6s
# [CV 4/5; 9/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 4/5; 9/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.843 total time=   5.5s
# [CV 5/5; 9/54] START criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 5/5; 9/54] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.845 total time=   5.6s
# [CV 1/5; 10/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 1/5; 10/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.856 total time=   3.8s
# [CV 2/5; 10/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 2/5; 10/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.855 total time=   3.7s
# [CV 3/5; 10/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 3/5; 10/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.852 total time=   3.8s
# [CV 4/5; 10/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 4/5; 10/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.851 total time=   3.9s
# [CV 5/5; 10/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 5/5; 10/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.856 total time=   3.8s
# [CV 1/5; 11/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 1/5; 11/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.859 total time=  39.1s
# [CV 2/5; 11/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 2/5; 11/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.852 total time=   3.7s
# [CV 3/5; 11/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 3/5; 11/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.853 total time=   5.1s
# [CV 4/5; 11/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 4/5; 11/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.851 total time=   5.7s
# [CV 5/5; 11/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 5/5; 11/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.854 total time=   5.7s
# [CV 1/5; 12/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 1/5; 12/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.859 total time=   7.6s
# [CV 2/5; 12/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 2/5; 12/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.852 total time=   7.6s
# [CV 3/5; 12/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 3/5; 12/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.853 total time=   7.6s
# [CV 4/5; 12/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 4/5; 12/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.854 total time=   7.6s
# [CV 5/5; 12/54] START criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 5/5; 12/54] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.855 total time=   7.5s
# [CV 1/5; 13/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 1/5; 13/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.858 total time=   3.6s
# [CV 2/5; 13/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 2/5; 13/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.853 total time=   3.6s
# [CV 3/5; 13/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 3/5; 13/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.853 total time=   3.6s
# [CV 4/5; 13/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 4/5; 13/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.853 total time=   3.6s
# [CV 5/5; 13/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 5/5; 13/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.855 total time=   3.6s
# [CV 1/5; 14/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 1/5; 14/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.858 total time=   5.5s
# [CV 2/5; 14/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 2/5; 14/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.852 total time=   5.5s
# [CV 3/5; 14/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 3/5; 14/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.852 total time=   5.4s
# [CV 4/5; 14/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 4/5; 14/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.854 total time=   5.4s
# [CV 5/5; 14/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 5/5; 14/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.853 total time=   5.4s
# [CV 1/5; 15/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 1/5; 15/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.858 total time=   7.3s
# [CV 2/5; 15/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 2/5; 15/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.853 total time=   7.3s
# [CV 3/5; 15/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 3/5; 15/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.854 total time=   7.3s
# [CV 4/5; 15/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 4/5; 15/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.851 total time=   7.2s
# [CV 5/5; 15/54] START criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 5/5; 15/54] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.853 total time=   7.3s
# [CV 1/5; 16/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 1/5; 16/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.857 total time=   3.4s
# [CV 2/5; 16/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 2/5; 16/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.852 total time=   3.4s
# [CV 3/5; 16/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 3/5; 16/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.853 total time=   3.4s
# [CV 4/5; 16/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 4/5; 16/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.851 total time=   3.4s
# [CV 5/5; 16/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 5/5; 16/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.850 total time=   3.4s
# [CV 1/5; 17/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 1/5; 17/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.857 total time=   5.1s
# [CV 2/5; 17/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 2/5; 17/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.851 total time=   5.2s
# [CV 3/5; 17/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 3/5; 17/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.854 total time=   5.2s
# [CV 4/5; 17/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 4/5; 17/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.849 total time=   5.2s
# [CV 5/5; 17/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 5/5; 17/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.852 total time=   5.3s
# [CV 1/5; 18/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 1/5; 18/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.855 total time=   7.6s
# [CV 2/5; 18/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 2/5; 18/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.852 total time=   7.1s
# [CV 3/5; 18/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 3/5; 18/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.855 total time=16.1min
# [CV 4/5; 18/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 4/5; 18/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.851 total time=   5.3s
# [CV 5/5; 18/54] START criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 5/5; 18/54] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.854 total time=   7.1s
# [CV 1/5; 19/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 1/5; 19/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.857 total time=   3.9s
# [CV 2/5; 19/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 2/5; 19/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.850 total time=   3.9s
# [CV 3/5; 19/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 3/5; 19/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.850 total time=   3.9s
# [CV 4/5; 19/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 4/5; 19/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.850 total time=   3.9s
# [CV 5/5; 19/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 5/5; 19/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.848 total time=   3.9s
# [CV 1/5; 20/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 1/5; 20/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.857 total time=   5.9s
# [CV 2/5; 20/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 2/5; 20/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.851 total time=   6.0s
# [CV 3/5; 20/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 3/5; 20/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.850 total time=   5.9s
# [CV 4/5; 20/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 4/5; 20/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.852 total time=   5.9s
# [CV 5/5; 20/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 5/5; 20/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.854 total time=   6.4s
# [CV 1/5; 21/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 1/5; 21/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.856 total time=   7.9s
# [CV 2/5; 21/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 2/5; 21/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.850 total time=   7.9s
# [CV 3/5; 21/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 3/5; 21/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.850 total time=   7.8s
# [CV 4/5; 21/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 4/5; 21/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.853 total time=   7.9s
# [CV 5/5; 21/54] START criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 5/5; 21/54] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.854 total time=   7.9s
# [CV 1/5; 22/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 1/5; 22/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.857 total time=   3.7s
# [CV 2/5; 22/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 2/5; 22/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.850 total time=   3.7s
# [CV 3/5; 22/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 3/5; 22/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.851 total time=   3.7s
# [CV 4/5; 22/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 4/5; 22/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.852 total time=   3.7s
# [CV 5/5; 22/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 5/5; 22/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.854 total time=   3.7s
# [CV 1/5; 23/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 1/5; 23/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.856 total time=   5.6s
# [CV 2/5; 23/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 2/5; 23/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.851 total time=   5.6s
# [CV 3/5; 23/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 3/5; 23/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.853 total time=   5.6s
# [CV 4/5; 23/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 4/5; 23/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.852 total time=   5.6s
# [CV 5/5; 23/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 5/5; 23/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.854 total time=   5.6s
# [CV 1/5; 24/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 1/5; 24/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.857 total time=   7.5s
# [CV 2/5; 24/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 2/5; 24/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.851 total time=   7.4s
# [CV 3/5; 24/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 3/5; 24/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.852 total time=   7.5s
# [CV 4/5; 24/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 4/5; 24/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.851 total time=   7.6s
# [CV 5/5; 24/54] START criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 5/5; 24/54] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.852 total time=   7.6s
# [CV 1/5; 25/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 1/5; 25/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.855 total time=   3.5s
# [CV 2/5; 25/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 2/5; 25/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.853 total time=   3.7s
# [CV 3/5; 25/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 3/5; 25/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.852 total time=   3.6s
# [CV 4/5; 25/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 4/5; 25/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.848 total time=   3.6s
# [CV 5/5; 25/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 5/5; 25/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.852 total time=11.6min
# [CV 1/5; 26/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 1/5; 26/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.855 total time=   3.6s
# [CV 2/5; 26/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 2/5; 26/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.851 total time=   4.8s
# [CV 3/5; 26/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 3/5; 26/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.853 total time=   5.6s
# [CV 4/5; 26/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 4/5; 26/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.849 total time=   5.6s
# [CV 5/5; 26/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 5/5; 26/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.853 total time=   5.7s
# [CV 1/5; 27/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 1/5; 27/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.855 total time=   7.7s
# [CV 2/5; 27/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 2/5; 27/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.849 total time=   8.0s
# [CV 3/5; 27/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 3/5; 27/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.7s
# [CV 4/5; 27/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 4/5; 27/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.848 total time=   7.5s
# [CV 5/5; 27/54] START criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 5/5; 27/54] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.853 total time=   7.9s
# [CV 1/5; 28/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 1/5; 28/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.849 total time=   3.2s
# [CV 2/5; 28/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 2/5; 28/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.848 total time=   3.3s
# [CV 3/5; 28/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 3/5; 28/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.849 total time=   3.3s
# [CV 4/5; 28/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 4/5; 28/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.842 total time=   3.1s
# [CV 5/5; 28/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 5/5; 28/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.848 total time=   3.3s
# [CV 1/5; 29/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 1/5; 29/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.849 total time=   4.9s
# [CV 2/5; 29/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 2/5; 29/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.848 total time=   4.9s
# [CV 3/5; 29/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 3/5; 29/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.850 total time=   4.7s
# [CV 4/5; 29/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 4/5; 29/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.846 total time=   4.8s
# [CV 5/5; 29/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 5/5; 29/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.848 total time=   4.8s
# [CV 1/5; 30/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 1/5; 30/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.848 total time=   6.5s
# [CV 2/5; 30/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 2/5; 30/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.847 total time=   6.4s
# [CV 3/5; 30/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 3/5; 30/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.848 total time=   6.3s
# [CV 4/5; 30/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 4/5; 30/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.845 total time=   6.4s
# [CV 5/5; 30/54] START criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200
# [CV 5/5; 30/54] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.849 total time=   6.2s
# [CV 1/5; 31/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 1/5; 31/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.846 total time=   3.2s
# [CV 2/5; 31/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 2/5; 31/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.849 total time=   3.1s
# [CV 3/5; 31/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 3/5; 31/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.848 total time=   3.1s
# [CV 4/5; 31/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 4/5; 31/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.843 total time=   3.1s
# [CV 5/5; 31/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100
# [CV 5/5; 31/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.846 total time=   3.1s
# [CV 1/5; 32/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 1/5; 32/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.847 total time=   4.5s
# [CV 2/5; 32/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 2/5; 32/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.846 total time=   4.8s
# [CV 3/5; 32/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 3/5; 32/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.850 total time=   4.6s
# [CV 4/5; 32/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 4/5; 32/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.843 total time=   4.7s
# [CV 5/5; 32/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150
# [CV 5/5; 32/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.844 total time=   4.7s
# [CV 1/5; 33/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 1/5; 33/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.848 total time=   6.2s
# [CV 2/5; 33/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 2/5; 33/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.848 total time=   6.4s
# [CV 3/5; 33/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 3/5; 33/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.852 total time=   6.3s
# [CV 4/5; 33/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 4/5; 33/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.843 total time=   6.5s
# [CV 5/5; 33/54] START criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200
# [CV 5/5; 33/54] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.846 total time=   6.3s
# [CV 1/5; 34/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 1/5; 34/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.844 total time=   2.9s
# [CV 2/5; 34/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 2/5; 34/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.844 total time=   2.9s
# [CV 3/5; 34/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 3/5; 34/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.847 total time=   2.8s
# [CV 4/5; 34/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 4/5; 34/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.842 total time=   2.8s
# [CV 5/5; 34/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100
# [CV 5/5; 34/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.846 total time=   3.0s
# [CV 1/5; 35/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 1/5; 35/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.846 total time=   4.3s
# [CV 2/5; 35/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 2/5; 35/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.846 total time=   4.3s
# [CV 3/5; 35/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 3/5; 35/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.848 total time=   4.4s
# [CV 4/5; 35/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 4/5; 35/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.841 total time=   4.4s
# [CV 5/5; 35/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150
# [CV 5/5; 35/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.845 total time=   4.3s
# [CV 1/5; 36/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 1/5; 36/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.845 total time=   5.8s
# [CV 2/5; 36/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 2/5; 36/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.845 total time=   5.9s
# [CV 3/5; 36/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 3/5; 36/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.847 total time=   5.8s
# [CV 4/5; 36/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 4/5; 36/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.843 total time=   5.8s
# [CV 5/5; 36/54] START criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200
# [CV 5/5; 36/54] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.844 total time=   6.0s
# [CV 1/5; 37/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 1/5; 37/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.860 total time=   4.0s
# [CV 2/5; 37/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 2/5; 37/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.852 total time=   4.1s
# [CV 3/5; 37/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 3/5; 37/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.854 total time=   4.3s
# [CV 4/5; 37/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 4/5; 37/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.852 total time=   4.2s
# [CV 5/5; 37/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100
# [CV 5/5; 37/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.854 total time=   4.1s
# [CV 1/5; 38/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 1/5; 38/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.858 total time=   6.1s
# [CV 2/5; 38/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 2/5; 38/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.852 total time=   6.0s
# [CV 3/5; 38/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 3/5; 38/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.852 total time=   6.3s
# [CV 4/5; 38/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 4/5; 38/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.851 total time=   6.4s
# [CV 5/5; 38/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150
# [CV 5/5; 38/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.857 total time=   6.2s
# [CV 1/5; 39/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 1/5; 39/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.857 total time=   8.5s
# [CV 2/5; 39/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 2/5; 39/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.852 total time=   8.3s
# [CV 3/5; 39/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 3/5; 39/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.853 total time=   8.5s
# [CV 4/5; 39/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 4/5; 39/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.854 total time=   8.5s
# [CV 5/5; 39/54] START criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200
# [CV 5/5; 39/54] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.853 total time=   8.2s
# [CV 1/5; 40/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 1/5; 40/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.856 total time=   3.8s
# [CV 2/5; 40/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 2/5; 40/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.852 total time=   3.8s
# [CV 3/5; 40/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 3/5; 40/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.854 total time=   3.9s
# [CV 4/5; 40/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 4/5; 40/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.851 total time=   4.0s
# [CV 5/5; 40/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100
# [CV 5/5; 40/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.855 total time=   4.1s
# [CV 1/5; 41/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 1/5; 41/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.858 total time=   6.1s
# [CV 2/5; 41/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 2/5; 41/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.852 total time=   6.1s
# [CV 3/5; 41/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 3/5; 41/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.852 total time=   6.0s
# [CV 4/5; 41/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 4/5; 41/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.853 total time=   6.2s
# [CV 5/5; 41/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150
# [CV 5/5; 41/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.856 total time=   6.1s
# [CV 1/5; 42/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 1/5; 42/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.855 total time=   8.1s
# [CV 2/5; 42/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 2/5; 42/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.852 total time=   8.1s
# [CV 3/5; 42/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 3/5; 42/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.852 total time=   8.1s
# [CV 4/5; 42/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 4/5; 42/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.852 total time=   8.3s
# [CV 5/5; 42/54] START criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200
# [CV 5/5; 42/54] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.854 total time=   8.1s
# [CV 1/5; 43/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 1/5; 43/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.857 total time=   3.8s
# [CV 2/5; 43/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 2/5; 43/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.850 total time=   3.8s
# [CV 3/5; 43/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 3/5; 43/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.854 total time=   3.9s
# [CV 4/5; 43/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 4/5; 43/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.848 total time=   3.8s
# [CV 5/5; 43/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100
# [CV 5/5; 43/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.850 total time=   3.9s
# [CV 1/5; 44/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 1/5; 44/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.858 total time=   5.8s
# [CV 2/5; 44/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 2/5; 44/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.851 total time=   5.6s
# [CV 3/5; 44/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 3/5; 44/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.855 total time=   5.8s
# [CV 4/5; 44/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 4/5; 44/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.851 total time=   5.7s
# [CV 5/5; 44/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150
# [CV 5/5; 44/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.851 total time=   6.0s
# [CV 1/5; 45/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 1/5; 45/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.856 total time=   7.6s
# [CV 2/5; 45/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 2/5; 45/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.852 total time=   7.8s
# [CV 3/5; 45/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 3/5; 45/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.855 total time=   7.8s
# [CV 4/5; 45/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 4/5; 45/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.8s
# [CV 5/5; 45/54] START criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200
# [CV 5/5; 45/54] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.9s
# [CV 1/5; 46/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 1/5; 46/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.858 total time=   4.5s
# [CV 2/5; 46/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 2/5; 46/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.851 total time=   4.2s
# [CV 3/5; 46/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 3/5; 46/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.848 total time=   4.2s
# [CV 4/5; 46/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 4/5; 46/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.851 total time=   4.5s
# [CV 5/5; 46/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100
# [CV 5/5; 46/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.852 total time=   4.3s
# [CV 1/5; 47/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 1/5; 47/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.856 total time=   6.7s
# [CV 2/5; 47/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 2/5; 47/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.852 total time=   6.6s
# [CV 3/5; 47/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 3/5; 47/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.851 total time=   6.8s
# [CV 4/5; 47/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 4/5; 47/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.849 total time=   6.4s
# [CV 5/5; 47/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150
# [CV 5/5; 47/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.855 total time=   6.6s
# [CV 1/5; 48/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 1/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.856 total time=   9.1s
# [CV 2/5; 48/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 2/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.852 total time=   8.9s
# [CV 3/5; 48/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 3/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.853 total time=   8.8s
# [CV 4/5; 48/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 4/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.853 total time=   8.8s
# [CV 5/5; 48/54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 5/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.852 total time=   8.9s
# [CV 1/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 1/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.860 total time=   4.2s
# [CV 2/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 2/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.852 total time=   4.2s
# [CV 3/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 3/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.850 total time=   4.2s
# [CV 4/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 4/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.850 total time=   4.1s
# [CV 5/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 5/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.855 total time=   4.2s
# [CV 1/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 1/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.857 total time=   6.3s
# [CV 2/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 2/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.852 total time=   6.4s
# [CV 3/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 3/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.852 total time=   6.4s
# [CV 4/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 4/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.853 total time=   6.4s
# [CV 5/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 5/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.855 total time=   6.1s
# [CV 1/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 1/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.858 total time=   8.2s
# [CV 2/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 2/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.850 total time=   8.2s
# [CV 3/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 3/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.852 total time=   8.4s
# [CV 4/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 4/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.851 total time=   8.0s
# [CV 5/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 5/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.852 total time=   8.0s
# [CV 1/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 1/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.857 total time=   3.7s
# [CV 2/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 2/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.850 total time=   3.8s
# [CV 3/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 3/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.851 total time=   3.7s
# [CV 4/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 4/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.848 total time=   3.7s
# [CV 5/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 5/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.854 total time=   3.7s
# [CV 1/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 1/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.854 total time=   5.6s
# [CV 2/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 2/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.853 total time=   5.7s
# [CV 3/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 3/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.853 total time=   5.6s
# [CV 4/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 4/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.849 total time=   5.6s
# [CV 5/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 5/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.854 total time=   5.7s
# [CV 1/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 1/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.858 total time=   7.6s
# [CV 2/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 2/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.6s
# [CV 3/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 3/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.5s
# [CV 4/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 4/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.6s
# [CV 5/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 5/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=   7.6s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [20, 30, 40],
#                          'min_samples_split': [3, 5, 8],
#                          'n_estimators': [100, 150, 200]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'min_samples_split': 3,
#  'n_estimators': 200}

# %% [markdown]
# #### Final Model

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 200, max_depth=30 ,min_samples_split= 3)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8640226628895185

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
#define metrics
y_pred_proba = Final_mod.predict(X_test)
fpr,tpr,_ = roc_curve(Y_test, y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8640249717274875

# %% [markdown]
# Conclusion:
#
# we had mix of columns like numeric and object type. Have checked numeric columns except capital_loss and again, other columns were having min and other percentile score. we saw outlier also in these numeric columns. Outlier handled with ZScore .
#
# we have done important analysis on categorical features with taregt variable and found certain interest facts like Workclass Private job people earning is high, from Sex columns we observed that male and female both are working in all the department/sector. Maximum people native country is United state thus we seen high earning for united state than other countries.we also observed that HS grad and some-collage are earning high from education columns.all categorical columns are Label Encoded.
#
# As we seen that target class was imbalance data set, it was bent to one side which was <=50K. imbalance problem was handled by up sampling with SMOTE algorithm.Model was trained on both the dataset, i got high accuracy with upsample data, thus have considered the same.

# %%
# Saving model

import joblib
joblib.dump(Final_mod,'Census_Income_Final.pkl')
# Out:
# ['Census_Income_Final.pkl']
