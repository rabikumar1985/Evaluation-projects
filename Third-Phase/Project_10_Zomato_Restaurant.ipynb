# %% [markdown]
# ## Zomato Restaurant

# %% [markdown]
# #### Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
#
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
#
# want to find the value for money restaurants in various parts of the country for the cuisines.
#
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
#
# the country and which locality of that country serves that cuisines with maximum number of
#
# restaurants.
#
# #### Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
#
# • Country code
#
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
#
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# #### Problem statement :
#
# In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range
#
#
# #### Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets

# %% [markdown]
# #### Dataset Link-
#
# •	https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
#
# •	https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
# Import Necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing DataSet 1

df1=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv",encoding="latin-1")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Importing DataSet 2

df2=pd.read_excel(r"C:\Users\Rabi Kumar\Assignment\Country-Code.xlsx")
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# Merge df1 and df2

df=pd.merge(df1,df2)
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### Statistical Analysis

# %%
# This will check if any duplicate entry 

df.duplicated().sum()
# Out:
# 0

# %%
# Let check if any whitespace, 'NA' or '-' exist in dataset.

df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
df.isin(['?']).sum().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# #### Missing value check

# %%
# Finding what percentage of data is missing from the dataset

missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                       Missing Values  % Missing data
# Cuisines                           9        0.094231
# Restaurant ID                      0        0.000000
# Has Table booking                  0        0.000000
# Votes                              0        0.000000
# Rating text                        0        0.000000
# Rating color                       0        0.000000
# Aggregate rating                   0        0.000000
# Price range                        0        0.000000
# Switch to order menu               0        0.000000
# Is delivering now                  0        0.000000
# Has Online delivery                0        0.000000
# Currency                           0        0.000000
# Restaurant Name                    0        0.000000
# Average Cost for two               0        0.000000
# Latitude                           0        0.000000
# Longitude                          0        0.000000
# Locality Verbose                   0        0.000000
# ...

# %% [markdown]
# #### Missing value imputation

# %%
df['Cuisines'].fillna(df['Cuisines'].mode()[0],inplace=True)

# %% [markdown]
# #### Missing Value Check After Imputataion

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                       Missing Values  % Missing data
# Restaurant ID                      0             0.0
# Restaurant Name                    0             0.0
# Votes                              0             0.0
# Rating text                        0             0.0
# Rating color                       0             0.0
# Aggregate rating                   0             0.0
# Price range                        0             0.0
# Switch to order menu               0             0.0
# Is delivering now                  0             0.0
# Has Online delivery                0             0.0
# Has Table booking                  0             0.0
# Currency                           0             0.0
# Average Cost for two               0             0.0
# Cuisines                           0             0.0
# Latitude                           0             0.0
# Longitude                          0             0.0
# Locality Verbose                   0             0.0
# ...

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="gist_earth")
plt.show()

# %% [markdown]
# Comment :
#
# Finally, No Missing Value is Present.

# %%
# Droping Restaurant ID column
df.drop("Restaurant ID",axis=1,inplace=True)

# %%
# Separating numerical and categorical variable

Numerical=['Country Code','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']

Category=['Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines','Currency','Has Table booking',
         'Has Online delivery','Is delivering now','Switch to order menu','Rating color','Rating text','Country']

# %%
# Statistical Matrix

df.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %%
# Start Exploring categorial features with Enlisting Value counts & Sub-categories

for i in Category:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ...
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
# ...
# Address
# Sector 41, Noida                                                                         11
# Dilli Haat, INA, New Delhi                                                               11
# ...

# %% [markdown]
# #### Exploratory Data Analysis(EDA)

# %%
#  Exploration of Country

plt.figure(figsize=(15,10))
sns.countplot(x='Country',data=df)
print(df['Country'].value_counts())
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
#  Exploration of Has Online delivery

plt.figure(figsize=(10,5))
sns.countplot(x='Has Online delivery',data=df)
print(df['Has Online delivery'].value_counts())
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
#  Exploration of Has Table booking

plt.figure(figsize=(10,5))
sns.countplot(x='Has Table booking',data=df)
print(df['Has Table booking'].value_counts())
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %%
#  Exploration of Is delivering now

plt.figure(figsize=(10,5))
sns.countplot(x='Is delivering now',data=df)
print(df['Is delivering now'].value_counts())
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %% [markdown]
# #### Understanding the Rating aggregate, color and text

# %%
df3 = df[['Aggregate rating','Rating color', 'Rating text']]
df3 = df3.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df3
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# The above information helps us to understand the realation between Aggregate rating, color and text. We conclude the following color assigned to the ratings:
#
# Rating 0 — White — Not rated
#
# Rating 1.8 to 2.4 — Red — Poor
#
# Rating 2.5 to 3.4 — Orange — Average
#
# Rating 3.5 to 3.9 — Yellow — Good
#
# Rating 4.0 to 4.4 — Green — Very Good
#
# Rating 4.5 to 4.9 — Dark Green — Excellent
#
# Let us try to understand the spread of rating across restaurants

# %%
#  Exploration of Rating color

plt.figure(figsize=(10,5))
sns.countplot(x='Rating color',data=df)
print(df['Rating color'].value_counts())
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %%
#  Exploration of Currency

plt.figure(figsize=(20,5))
sns.countplot(x='Currency',data=df)
print(df['Currency'].value_counts())
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
# Exploration of Average Cost for two

sns.barplot(x='Average Cost for two',y='Country',data=df,color='c')
plt.title("Average Cost for two vs Country",fontsize=10, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Average Cost for two vs Country')

# %%
plt.figure(figsize=(10,20))
sns.barplot(x='Average Cost for two',y='City',data=df,color='c')
plt.title("Average Cost for two vs City",fontsize=10, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Average Cost for two vs City')

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality  Locality Verbose  \
# 0             3749           162    73     8685       171               172
# 1             3173           162    73     6055       593               601
# 2             2897           162    75     4684       308               314
# 3             4707           162    75     8690       862               875
# 4             5523           162    75     8689       862               875
#
#     Longitude   Latitude  Cuisines  Average Cost for two  ...  \
# 0  121.027535  14.565443       920                  1100  ...
# 1  121.014101  14.553708      1111                  1200  ...
# 2  121.056831  14.581404      1671                  4000  ...
# 3  121.056475  14.585318      1126                  1500  ...
# 4  121.057508  14.584450      1122                  1500  ...
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# 0                  1                    0                  0
# ...

# %%
# Droping Restaurant Switch to order menu
df.drop("Switch to order menu",axis=1,inplace=True)

# %%
# Heatmap Visualization

plt.figure(figsize =(15,10))
sns.heatmap(df.corr(), annot= True ,cmap='rainbow') 

plt.tight_layout
plt.show()

# %% [markdown]
# #### Feature selection and Engineering

# %%
# Outliers removal using Zscore method

from scipy.stats import zscore

z = np.abs(zscore(df))
threshold = 3
df4 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df4.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df4.shape[0])/df.shape[0]*100)

df=df4.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (9551, 20)
# Shape of the dataframe after removing outliers:  (8408, 20)
# Percentage of data loss post outlier removal:  11.967333263532614

# %% [markdown]
# We are losing 11.96 % of data. Its big but we can afford it. Considering we have a lot of rows in our datatset for ML model building.

# %%
# Skewness of features

plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
# Now we can drop  column 
df.drop("Is delivering now",axis=1,inplace=True)

# %%
df.drop("Restaurant Name",axis=1,inplace=True)
df.drop("Country Code",axis=1,inplace=True)
df.drop("City",axis=1,inplace=True)
df.drop("Address",axis=1,inplace=True)
df.drop("Locality",axis=1,inplace=True)
df.drop("Locality Verbose",axis=1,inplace=True)
df.drop("Currency",axis=1,inplace=True)
df.drop("Aggregate rating",axis=1,inplace=True)
df.drop("Rating color",axis=1,inplace=True)
df.drop("Votes",axis=1,inplace=True)
df.drop("Rating text",axis=1,inplace=True)
df.drop("Country",axis=1,inplace=True)

# %%
# Skewness

df.skew()
# Out:
# Longitude              -3.702347
# Latitude               -3.241005
# Cuisines               -0.345840
# Average Cost for two    3.716607
# Has Table booking       2.269837
# Has Online delivery     1.001452
# Price range             1.054225
# dtype: float64

# %%
# Making the skew less than or equal to +0.5 and -0.5 for better prediction using yeo-johnson method

skew=['Longitude','Latitude','Average Cost for two','Price range','Has Table booking','Has Online delivery']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[skew] = scaler.fit_transform(df[skew].values)

# %%
# Corrleation

df.corr()
# Out:
#                       Longitude  Latitude  Cuisines  Average Cost for two  \
# Longitude              1.000000  0.652157  0.009278              0.017640
# Latitude               0.652157  1.000000  0.036038             -0.023185
# Cuisines               0.009278  0.036038  1.000000             -0.006094
# Average Cost for two   0.017640 -0.023185 -0.006094              1.000000
# Has Table booking      0.050592  0.060831  0.043720              0.571394
# Has Online delivery    0.115584  0.158441 -0.042408              0.202744
# Price range            0.067161 -0.095284  0.021578              0.826056
#
#                       Has Table booking  Has Online delivery  Price range
# Longitude                      0.050592             0.115584     0.067161
# Latitude                       0.060831             0.158441    -0.095284
# Cuisines                       0.043720            -0.042408     0.021578
# Average Cost for two           0.571394             0.202744     0.826056
# ...

# %%
df.skew()
# Out:
# Longitude               0.348925
# Latitude               -2.648645
# Cuisines               -0.345840
# Average Cost for two    0.015928
# Has Table booking       2.269837
# Has Online delivery     1.001452
# Price range             0.252381
# dtype: float64

# %%
plt.figure(figsize = (18,6))
df.corr()['Average Cost for two'].drop(['Average Cost for two']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Average Cost for two',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Average Cost for two',fontsize = 20,fontweight='bold')
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Price range'].drop(['Price range']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Price range',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Price range',fontsize = 20,fontweight='bold')
plt.show()

# %% [markdown]
# #### Machine Learning Model Building

# %%
# Splitting data in target and dependent feature
X = df.drop(['Average Cost for two'], axis =1)
Y = df['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
### PCA

from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression , Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
# Seprating data into X and Y, since it has two target variance thus kept y1 an y2
X_new = df.drop(columns =["Average Cost for two","Price range"], axis=1)
y1_new = df["Average Cost for two"]
y2_new = df["Price range"]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X_new)

# %%
# Average Cost for two prediction

for i in range(40,300,60):
    X_train1,X_test1,y1_train,y1_test = train_test_split(X_new,y1_new, test_size =0.2, random_state = i)
    LR1_new = LinearRegression()
    LR1_new.fit(X_train1,y1_train)
    pred= LR1_new.predict(X_test1)
    print("r2score",r2_score(y1_test, pred),"Random",i)
    print("mean_squared_error",mean_squared_error(y1_test, pred),"\n")
# Out:
# r2score 0.3680588298489288 Random 40
# mean_squared_error 0.5978221467095285
#
# r2score 0.35354650640631824 Random 100
# mean_squared_error 0.62858917119881
#
# r2score 0.3649343040817944 Random 160
# mean_squared_error 0.6503364022848144
#
# r2score 0.4035090051891673 Random 220
# mean_squared_error 0.6075096093265651
#
# r2score 0.3456274844750433 Random 280
# mean_squared_error 0.6165520780309591

# %%
# Price range prediction

for i in range(40,300,60):
    X_train2,X_test2,y2_train,y2_test = train_test_split(X_new,y2_new, test_size =0.2, random_state = i)
    LR2_new = LinearRegression()
    LR2_new.fit(X_train2,y2_train)
    pred= LR2_new.predict(X_test2)
    print("r2score",r2_score(y2_test, pred),"Random",i)
    print("mean_squared_error",mean_squared_error(y2_test, pred),"\n")
# Out:
# r2score 0.31811053889615426 Random 40
# mean_squared_error 0.6689784686452794
#
# r2score 0.3326054753383929 Random 100
# mean_squared_error 0.6610233885475189
#
# r2score 0.335761683451528 Random 160
# mean_squared_error 0.6587039413352446
#
# r2score 0.3548240891178902 Random 220
# mean_squared_error 0.6499710043912725
#
# r2score 0.32163717206720244 Random 280
# mean_squared_error 0.6773366916303687

# %%
Model1 =  [Lasso() , Ridge(),RandomForestRegressor(),GradientBoostingRegressor(), 
           KNeighborsRegressor(),DecisionTreeRegressor()]
           
Model2  = [Lasso() , Ridge(),RandomForestRegressor(),GradientBoostingRegressor(), 
           KNeighborsRegressor(),DecisionTreeRegressor()]

# %%
# Average Cost for two Prediction

for i in Model1:
    X_train1,X_test1,y1_train,y1_test = train_test_split(X_new,y1_new, test_size =0.2, random_state = 220)
    i.fit(X_train1,y1_train)
    pred= i.predict(X_test1)
    print("r2score",r2_score(y1_test, pred),i)
    print("mean_squared_error",mean_squared_error(y1_test, pred),"\n")
# Out:
# r2score -0.0020515848698503536 Lasso()
# mean_squared_error 1.0205618729288697
#
# r2score 0.4035037561811804 Ridge()
# mean_squared_error 0.6075149552962766
#
# r2score 0.6577793029942955 RandomForestRegressor()
# mean_squared_error 0.3485423313177312
#
# r2score 0.6198738171442626 GradientBoostingRegressor()
# mean_squared_error 0.3871480221000204
#
# r2score 0.56346443251843 KNeighborsRegressor()
# mean_squared_error 0.4445994228998924
#
# r2score 0.39244855100285625 DecisionTreeRegressor()
# mean_squared_error 0.6187743765404122

# %% [markdown]
# Randomforest is working good as compared to other models, we will selected Randomforest as final one and train further

# %%
# Price range Prediction

for i in Model2:
    X_train2,X_test2,y2_train,y2_test = train_test_split(X_new,y2_new, test_size =0.2, random_state = 280)
    i.fit(X_train2,y2_train)
    pred= i.predict(X_test2)
    
    print('r2score',r2_score(y2_test, pred),i)
    print("mean_squared_error",mean_squared_error(y2_test, pred),"\n")
# Out:
# r2score 1.8832342846053507e-05 Lasso()
# mean_squared_error 0.9984685302666217
#
# r2score 0.32163394591940364 Ridge()
# mean_squared_error 0.6773399128980837
#
# r2score 0.4911035369723039 RandomForestRegressor()
# mean_squared_error 0.5081266727128557
#
# r2score 0.5027856012744809 GradientBoostingRegressor()
# mean_squared_error 0.49646227947072824
#
# r2score 0.465537527710845 KNeighborsRegressor()
# mean_squared_error 0.533654009144479
#
# r2score 0.194554232762167 DecisionTreeRegressor()
# mean_squared_error 0.8042273969094954

# %% [markdown]
# GradientBoostingRegressor is working good as compared to other models, we will selected GradientBoostingRegressor as final one and train further

# %% [markdown]
# #### Cross Validation

# %%
for m in Model1:
    score = cross_val_score(m, X_scale, y1_new, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : Lasso() :
#
# Mean CV Score : -0.03058357495181028
# ...
#
#
# Cross Validation Score : Ridge() :
#
# Mean CV Score : 0.33356460342225563
# ...
#
#
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.5422872320855792
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.5419316761364362
# ...
#
#
# Cross Validation Score : KNeighborsRegressor() :
#
# Mean CV Score : 0.5066518117092237
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.19168171682770557
# ...

# %%
for m in Model2:
    score = cross_val_score(m, X_scale, y2_new, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : Lasso() :
#
# Mean CV Score : -0.0469145303495611
# ...
#
#
# Cross Validation Score : Ridge() :
#
# Mean CV Score : 0.3021504341847964
# ...
#
#
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.44644838511688006
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.484478951464137
# ...
#
#
# Cross Validation Score : KNeighborsRegressor() :
#
# Mean CV Score : 0.4486890706444721
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -0.06207958284004182
# ...

# %% [markdown]
# #### Hyper Parameter Tuning : GridSearchCV

# %%
# Average Cost for two prediction
RF_y1 = RandomForestRegressor()

para_y1 = {"n_estimators" :[100,150,200,250,300],
          "max_depth" : [2,3,4,5,6,7],
          "min_samples_split" :[2,3,4,5]}

grid_search = GridSearchCV(RF_y1,para_y1, scoring = "r2", cv = 5, n_jobs = -1, verbose = 2)
grid_search.fit(X_train1,y1_train)
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# {'max_depth': 7, 'min_samples_split': 5, 'n_estimators': 200}

# %%
# Price range prediction

GB_y2 = GradientBoostingRegressor()

para_y2 = {"n_estimators" :[100.200,250,300],
          "max_depth" : [2,3,4,5,6,7],
          "min_samples_split" :[2,3,4,5]}

grid_search2 = GridSearchCV(GB_y2,para_y2, scoring = "r2", cv = 5, n_jobs = -1, verbose = 2)
grid_search2.fit(X_train2,y2_train)
print(grid_search2.best_params_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 300}

# %% [markdown]
# #### Final Regression Model

# %%
from xgboost import XGBRegressor

# Final Model Average Cost for two

Final_mod1 =  XGBRegressor(n_estimators=200 ,max_depth = 7 )
Final_mod1.fit(X_train1,y1_train)
y_pred=Final_mod1.predict(X_test1)
print('\n')                                        
print('\033[1m'+' Error in Final Model1 Next_tmin :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(y1_test,pred))
print('Mean squared error :', mean_squared_error(y1_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y1_test,pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model1 Next_tmin :'+'\033[0m')
print(r2_score(y1_test,pred)) 
print('\n')
# Out:
#  Error in Final Model1 Next_tmin :
# Mean absolute error : 1.1526464749874477
# Mean squared error : 1.9954345740763084
# Root Mean Squared Error: 1.412598518361218
#
#
#  R2 Score of Final Model1 Next_tmin :
# -0.959242678465827

# %%
# Final Model Price range

Final_mod2 =  XGBRegressor(n_estimators=300 ,max_depth = 4 )
Final_mod2.fit(X_train2,y2_train)
y_pred=Final_mod2.predict(X_test2)
print('\n')                                        
print('\033[1m'+' Error in Final Model2  Next_tmix :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(y2_test,pred))
print('Mean squared error :', mean_squared_error(y2_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y2_test,pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model2  Next_tmix :'+'\033[0m')
print(r2_score(y2_test,pred)) 
print('\n')
# Out:
#  Error in Final Model2  Next_tmix :
# Mean absolute error : 0.5124842409971255
# Mean squared error : 0.8042273969094954
# Root Mean Squared Error: 0.8967872640205677
#
#
#  R2 Score of Final Model2  Next_tmix :
# 0.194554232762167

# %%
# Saving Final Model

import joblib
joblib.dump(Final_mod1,'Average_Cost_for_two.pkl')

joblib.dump(Final_mod2,'Price_range.pkl')
# Out:
# ['Price_range.pkl']
